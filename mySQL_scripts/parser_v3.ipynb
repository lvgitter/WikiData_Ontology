# %%
#parser: given owl, set up db and write mappings

# %%
with open ("../books/books_20_07.owl", "r") as fowl:
    content = fowl.read()
    i = 0
    lines = content.split("\n")
    outstring = ""
    dict_classes = {}
    dict_relations = {}
    dict_attributes = {}
    while (i < len(lines)):
        
        line = lines[i]
        
        if ("follows") in line or ("bo:author_genre" in line and "bo:Book" in line):
            i += 1
            continue
        
        if "Prefix" in lines[i]:
            i += 1
            continue

        if "Declaration(Class" in lines[i]: #from now on, work on this class
            classe = line.split(":")[1][:-2]
            dict_classes[classe] = {}
            dict_classes[classe]["attributes"] = {}
            i += 1
            continue
            
        if "Declaration(ObjectProperty" in lines[i]:
            relation = line.split(":")[1][:-2]
            dict_relations[relation] = {}
            dict_relations[relation]["functional"] = False
            dict_relations[relation]["inv_functional"] = False
            i += 1
            continue
        
        if "Declaration(DataProperty" in lines[i]:
            attribute = line.split(":")[1][:-2]
            dict_attributes[attribute] = {}
            dict_attributes[attribute]["functional"] = False
            dict_attributes[attribute]["inv_functional"] = False
            i += 1
            continue
            
        if "ObjectPropertyDomain" in lines[i]:
            relation = line.split(" ")[0].split(":")[-1]
            domain = line.split(":")[-1][:-1]
            dict_relations[relation]["domain"] = {}
            dict_relations[relation]["domain"]["name"] = domain
            dict_relations[relation]["domain"]["nullable"] = True
            i += 1
            continue
            
        if "DataPropertyDomain" in lines[i]:
            attribute = line.split(" ")[0].split(":")[-1]
            domain = line.split(":")[-1][:-1]
            dict_attributes[attribute]["domain"] = {}
            dict_attributes[attribute]["domain"]["name"] = domain
            dict_attributes[attribute]["domain"]["nullable"] = True
            i += 1
            continue
        
        if "ObjectPropertyRange" in lines[i]:
            relation = line.split(" ")[0].split(":")[-1]
            range_ = line.split(":")[-1][:-1]
            dict_relations[relation]["range"] = {}
            dict_relations[relation]["range"]["name"] = range_
            dict_relations[relation]["range"]["nullable"] = True
            i += 1
            continue
            
        if "DataPropertyRange" in lines[i]:
            attribute = line.split(" ")[0].split(":")[-1]
            range_ = line.split(":")[-1][:-1]
            dict_attributes[attribute]["range"] = {}
            dict_attributes[attribute]["range"]["name"] = range_
            #dict_attributes[attribute]["range"]["nullable"] = True
            i += 1
            continue
        
        if "FunctionalObjectProperty" in lines[i]:
            relation = line.split(":")[-1][:-1]
            dict_relations[relation]["functional"] = True
            i += 1
            continue
            
        if "FunctionalDataProperty" in lines[i]:
            attribute = line.split(":")[-1][:-1]
            dict_attributes[attribute]["functional"] = True
            i += 1
            continue

        if "EquivalentClasses" in lines[i] and "Thing" in lines[i]:
            relation = line.split(":")[2].split(" ")[0].replace(")", "")
            if "ObjectInverseOf" not in lines[i]:
                domain = line.split(":")[1].split(" ")[0]
                dict_relations[relation]["domain"]["nullable"] = False
            else:
                range_ = line.split(":")[1].split(" ")[0]
                dict_relations[relation]["range"]["nullable"] = False
            i += 1
            continue
            
        if "EquivalentClasses" in lines[i] and "rdf" in lines[i]:
            attribute = line.split(":")[2].split(" ")[0].replace(")", "")
            domain = line.split(":")[1].split(" ")[0]
            dict_attributes[attribute]["domain"]["nullable"] = False #no need to work on the range
            i += 1
            continue
        
        if "SubClassOf" in lines[i] and "ObjectUnionOf" not in lines[i]:
            father = line.split(":")[2].replace(")", "")
            child = line.split(":")[1].split(" ")[0]
            dict_classes[child]["isa"] = father
            i += 1
            continue
            
        i += 1

print(dict_classes)
print("************************")
print (dict_relations)
print("************************")
print (dict_attributes)
# Out:
# {'Book': {'attributes': {}}, 'FictionalCity': {'attributes': {}}, 'Mayor': {'attributes': {}}, 'Author': {'isa': 'Human', 'attributes': {}}, 'City': {'attributes': {}}, 'Character': {'attributes': {}}, 'Translator': {'isa': 'Human', 'attributes': {}}, 'Language': {'attributes': {}}, 'RealCity': {'attributes': {}}, 'FictionalCharacter': {'isa': 'Character', 'attributes': {}}, 'Country': {'attributes': {}}, 'FictionalHuman': {'attributes': {}}, 'Human': {'attributes': {}}, 'FictionalNotHuman': {'attributes': {}}, 'Publisher': {'attributes': {}}, 'Edition': {'attributes': {}}}
# ************************
# {'followedBy': {'range': {'nullable': True, 'name': 'Book'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Book'}}, 'hasTranslator': {'range': {'nullable': True, 'name': 'Translator'}, 'functional': False, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Edition'}}, 'hasUsedLanguage': {'range': {'nullable': False, 'name': 'Language'}, 'functional': False, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Country'}}, 'hasEdition': {'range': {'nullable': False, 'name': 'Edition'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Book'}}, 'hasCharacter': {'range': {'nullable': False, 'name': 'Character'}, 'functional': False, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Book'}}, 'hasRole': {'range': {'nullable': False, 'name': 'Mayor'}, 'functional': False, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Human'}}, 'hasCityLocation': {'range': {'nullable': True, 'name': 'City'}, 'functional': False, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Book'}}, 'hasForewordAuthor': {'range': {'nullable': True, 'name': 'Author'}, 'functional': False, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Book'}}, 'InfluencedBy': {'range': {'nullable': True, 'name': 'Author'}, 'functional': False, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Author'}}, 'hasIllustrator': {'range': {'nullable': True, 'name': 'Human'}, 'functional': False, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Edition'}}, 'BookWrittenIn': {'range': {'nullable': True, 'name': 'Language'}, 'functional': False, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Book'}}, 'locatedIn': {'range': {'nullable': True, 'name': 'Country'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Publisher'}}, 'PlaceOfBirth': {'range': {'nullable': True, 'name': 'RealCity'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Human'}}, 'PlaceOfDeath': {'range': {'nullable': True, 'name': 'RealCity'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Human'}}, 'speaks': {'range': {'nullable': True, 'name': 'Language'}, 'functional': False, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Translator'}}, 'foundedBy': {'range': {'nullable': True, 'name': 'Human'}, 'functional': False, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Publisher'}}, 'hasMayor': {'range': {'nullable': False, 'name': 'Mayor'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'RealCity'}}, 'hasAnalog': {'range': {'nullable': True, 'name': 'RealCity'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'FictionalCity'}}, 'hasCountryLocation': {'range': {'nullable': True, 'name': 'Country'}, 'functional': False, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Book'}}, 'hasAuthor': {'range': {'nullable': False, 'name': 'Author'}, 'functional': False, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Book'}}, 'hasAfterwordAuthor': {'range': {'nullable': True, 'name': 'Author'}, 'functional': False, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Book'}}, 'hasCountry': {'range': {'nullable': True, 'name': 'Country'}, 'functional': False, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'RealCity'}}, 'hasPublisher': {'range': {'nullable': False, 'name': 'Publisher'}, 'functional': False, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Edition'}}}
# ************************
# {'book_id': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Book'}}, 'book_description': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Book'}}, 'mayor_description': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Mayor'}}, 'translator_label': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Translator'}}, 'area': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'RealCity'}}, 'num_speakers': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Language'}}, 'human_id': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Human'}}, 'mayor_label': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Mayor'}}, 'author_label': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Author'}}, 'translator_description': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Translator'}}, 'country_id': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Country'}}, 'award': {'range': {'name': 'string'}, 'functional': False, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Author'}}, 'edition_label': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Edition'}}, 'author_genre': {'range': {'name': 'string'}, 'functional': False, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Author'}}, 'edition_id': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Edition'}}, 'country_label': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Country'}}, 'sex': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Human'}}, 'human_description': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Human'}}, 'publisher_id': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Publisher'}}, 'name': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Human'}}, 'character_DoB': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Character'}}, 'publisher_label': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Publisher'}}, 'inception': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Publisher'}}, 'character_id': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Character'}}, 'character_name': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Character'}}, 'end_time': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Mayor'}}, 'language_description': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Language'}}, 'title': {'range': {'name': 'string'}, 'functional': True, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Book'}}, 'edition_description': {'range': {'name': 'stri ...

# %%
relazioni_da_accorpare = ["hasMayor"]
relazioni_da_accorpare = []
#'character_id': {'range': {'name': 'character_id> xsd:strin'}, 'domain': {'name': 'Character', 'nullable': False}, 'functional': True, 'inv_functional': False}

# %%
#dict_attributes.keys()

# %%
for attribute in dict_attributes.keys():
    if dict_attributes[attribute]["functional"] == False: #va reificata la ER-relazione e creata una nuova relazione
        #print(attribute, "**********attr")
        new_class = attribute.title()
        dict_classes[new_class] = {}
        dict_classes[new_class]["attributes"] = {}
        attribute_name = new_class.lower() + "_id"
        dict_classes[new_class]["attributes"][attribute_name] = {}
        dict_classes[new_class]["attributes"][attribute_name]["typ"] = "varchar (255)"
        dict_classes[new_class]["attributes"][attribute_name]["nullable"] = False

        new_relation = "has" + attribute.title()
        dict_relations[new_relation] = {}
        dict_relations[new_relation]["domain"] = {}
        dict_relations[new_relation]["domain"]["name"] = dict_attributes[attribute]["domain"]["name"]
        dict_relations[new_relation]["domain"]["nullable"] = dict_attributes[attribute]["domain"]["nullable"]
        dict_relations[new_relation]["range"] = {}
        dict_relations[new_relation]["range"]["name"] = new_class
        dict_relations[new_relation]["range"]["nullable"] = False
        dict_relations[new_relation]["functional"] = False
        dict_relations[new_relation]["inv_functional"] = False
    else: #assign attributes to classes
        class_ = dict_attributes[attribute]["domain"]["name"]
        #print(class_)
        nullable = dict_attributes[attribute]["domain"]["nullable"]
        typ = "varchar (255)"
        dict_classes[class_]["attributes"][attribute] = {}
        dict_classes[class_]["attributes"][attribute]["typ"] = typ
        dict_classes[class_]["attributes"][attribute]["nullable"] = nullable


for relation in dict_relations.keys():
    if relation in relazioni_da_accorpare and dict_relations[relation]["functional"] == True: #va accorpata, con precedenza sul dominio
        #print(relation, "**********")
        class_ = dict_relations[relation]["domain"]["name"]
        new_attribute = dict_relations[relation]["range"]["name"]
        nullable = dict_relations[relation]["domain"]["nullable"]
        typ = "varchar (255)"
        dict_classes[class_]["attributes"][relation] = {}
        dict_classes[class_]["attributes"][relation]["typ"] = typ
        dict_classes[class_]["attributes"][relation]["nullable"] = nullable
    elif relation in relazioni_da_accorpare and dict_relations[relation]["inv_functional"] == True:
        #print(relation, "*INV**********")
        class_ = dict_relations[relation]["range"]["name"]
        new_attribute = dict_relations[relation]["domain"]["name"]
        nullable = dict_relations[relation]["range"]["nullable"]
        typ = "varchar (255)"
        dict_classes[class_]["attributes"][relation] = {}
        dict_classes[class_]["attributes"][relation]["typ"] = typ
        dict_classes[class_]["attributes"][relation]["nullable"] = nullable
        dict_classes[class_]["attributes"][relation]["references"] = new_attribute
    else: 
        #print(relation)
        domain = dict_relations[relation]["domain"]["name"]
        range_ = dict_relations[relation]["range"]["name"]
        dict_classes[relation] = {}
        dict_classes[relation]["attributes"] = {}
        dict_classes[relation]["attributes"][domain.lower() + "_id"] = {}
        dict_classes[relation]["attributes"][domain.lower() + "_id"]["references"] = domain
        dict_classes[relation]["attributes"][domain.lower() + "_id"]["typ"] = "varchar (255)"
        dict_classes[relation]["attributes"][domain.lower() + "_id"]["nullable"] = dict_relations[relation]["domain"]["nullable"]
        dict_classes[relation]["attributes"][range_.lower() + "_id"] = {}
        dict_classes[relation]["attributes"][range_.lower() + "_id"]["references"] = range_
        dict_classes[relation]["attributes"][range_.lower() + "_id"]["typ"] = "varchar (255)"
        dict_classes[relation]["attributes"][range_.lower() + "_id"]["nullable"] = dict_relations[relation]["range"]["nullable"]

#is-a s
for class_ in dict_classes.keys():
    if "isa" in dict_classes[class_].keys():
        for attr in dict_classes[dict_classes[class_]["isa"]]:
            dict_classes[class_][attr] = dict_classes[dict_classes[class_]["isa"]][attr]
        
        
print(dict_classes)
print("************************")
'''print (dict_relations)
print("************************")
print (dict_attributes)    
print("************************")       '''
# Out:
# {'followedBy': {'attributes': {'book_id': {'typ': 'varchar (255)', 'references': 'Book', 'nullable': True}}}, 'Book': {'attributes': {'book_id': {'typ': 'varchar (255)', 'nullable': False}, 'book_description': {'typ': 'varchar (255)', 'nullable': False}, 'title': {'typ': 'varchar (255)', 'nullable': False}, 'subtitle': {'typ': 'varchar (255)', 'nullable': True}, 'book_label': {'typ': 'varchar (255)', 'nullable': False}}}, 'FictionalCity': {'attributes': {}}, 'Award': {'attributes': {'award_id': {'typ': 'varchar (255)', 'nullable': False}}}, 'Mayor': {'attributes': {'mayor_label': {'typ': 'varchar (255)', 'nullable': False}, 'end_time': {'typ': 'varchar (255)', 'nullable': True}, 'official_residence': {'typ': 'varchar (255)', 'nullable': False}, 'mayor_description': {'typ': 'varchar (255)', 'nullable': False}, 'start_time': {'typ': 'varchar (255)', 'nullable': False}, 'mayor_id': {'typ': 'varchar (255)', 'nullable': False}}}, 'Author': {'isa': 'Human', 'attributes': {'sex': {'typ': 'varchar (255)', 'nullable': False}, 'human_id': {'typ': 'varchar (255)', 'nullable': False}, 'human_label': {'typ': 'varchar (255)', 'nullable': False}, 'human_description': {'typ': 'varchar (255)', 'nullable': False}, 'DoD': {'typ': 'varchar (255)', 'nullable': True}, 'name': {'typ': 'varchar (255)', 'nullable': False}, 'DoB': {'typ': 'varchar (255)', 'nullable': False}}}, 'Language': {'attributes': {'language_id': {'typ': 'varchar (255)', 'nullable': False}, 'num_speakers': {'typ': 'varchar (255)', 'nullable': True}, 'language_description': {'typ': 'varchar (255)', 'nullable': False}, 'language_label': {'typ': 'varchar (255)', 'nullable': False}}}, 'hasCityLocation': {'attributes': {'book_id': {'typ': 'varchar (255)', 'references': 'Book', 'nullable': True}, 'city_id': {'typ': 'varchar (255)', 'references': 'City', 'nullable': True}}}, 'hasCharacter': {'attributes': {'book_id': {'typ': 'varchar (255)', 'references': 'Book', 'nullable': True}, 'character_id': {'typ': 'varchar (255)', 'references': 'Character', 'nullable': False}}}, 'hasEdition': {'attributes': {'book_id': {'typ': 'varchar (255)', 'references': 'Book', 'nullable': True}, 'edition_id': {'typ': 'varchar (255)', 'references': 'Edition', 'nullable': False}}}, 'Translator': {'isa': 'Human', 'attributes': {'sex': {'typ': 'varchar (255)', 'nullable': False}, 'human_id': {'typ': 'varchar (255)', 'nullable': False}, 'human_label': {'typ': 'varchar (255)', 'nullable': False}, 'human_description': {'typ': 'varchar (255)', 'nullable': False}, 'DoD': {'typ': 'varchar (255)', 'nullable': True}, 'name': {'typ': 'varchar (255)', 'nullable': False}, 'DoB': {'typ': 'varchar (255)', 'nullable': False}}}, 'hasTranslator': {'attributes': {'translator_id': {'typ': 'varchar (255)', 'references': 'Translator', 'nullable': True}, 'edition_id': {'typ': 'varchar (255)', 'references': 'Edition', 'nullable': True}}}, 'hasForewordAuthor': {'attributes': {'book_id': {'typ': 'varchar (255)', 'references': 'Book', 'nullable': True}, 'author_id': {'typ': 'varchar (255)', 'references': 'Author', 'nullable': True}}}, 'hasCountry': {'attributes': {'country_id': {'typ': 'varchar (255)', 'references': 'Country', 'nullable': True}, 'realcity_id': {'typ': 'varchar (255)', 'references': 'RealCity', 'nullable': False}}}, 'PlaceOfBirth': {'attributes': {'human_id': {'typ': 'varchar (255)', 'references': 'Human', 'nullable': False}, 'realcity_id': {'typ': 'varchar (255)', 'references': 'RealCity', 'nullable': True}}}, 'hasIllustrator': {'attributes': {'human_id': {'typ': 'varchar (255)', 'references': 'Human', 'nullable': True}, 'edition_id': {'typ': 'varchar (255)', 'references': 'Edition', 'nullable': True}}}, 'hasUsedLanguage': {'attributes': {'country_id': {'typ': 'varchar (255)', 'references': 'Country', 'nullable': False}, 'language_id': {'typ': 'varchar (255)', 'references': 'Language', 'nullable': False}}}, 'BookWrittenIn': {'attributes': {'book_id': {'typ': 'varchar (255)', 'references': 'Book', 'nullable': False}, 'l ...
# ************************
# 'print (dict_relations)\nprint("************************")\nprint (dict_attributes)    \nprint("************************")       '

# %%
#generate strings and write to file

# %%
outstring_create = "CREATE DATABASE bookDB;\n\nUSE bookDB;\n\n"
outstring_insert = ""

with open("create.sql", "w") as cf, open("insert.sql", "w") as insf:
    for class_ in dict_classes.keys():
        referencing = False
        outstring_create += "CREATE TABLE " + class_ + "(" + "\n"
        #print(class_)
        for attribute in dict_classes[class_]["attributes"]:
            outstring_create += "\t" + attribute
            outstring_create +=   " " + dict_classes[class_]["attributes"][attribute]["typ"] 
            if "_id" in attribute:
                outstring_create += " " + " primary key"
            elif not dict_classes[class_]["attributes"][attribute]["nullable"]:
                outstring_create += " " + "not null"
            outstring_create += ",\n"
            if "references" in (dict_classes[class_]["attributes"][attribute]).keys():
                referencing = True
                outstring_create += "\tforeign key " + \
                "("+ attribute + ") references " + \
                dict_classes[class_]["attributes"][attribute]["references"] + "(" + \
                dict_classes[class_]["attributes"][attribute]["references"].lower() + "_id),\n"
        '''for attribute in dict_classes[class_]["attributes"]:
            if "references" in (dict_classes[class_]["attributes"][attribute]).keys():
                outstring_create += "\tprimary key (" + attribute + "," + \
                dict_classes[class_]["attributes"][attribute]["references"].lower() + "_id),\n"'''
        outstring_create = outstring_create.rstrip()[:-1] #remove comma and newline
        outstring_create += ");\n\n" 

        if referencing:
            relative_path = "../roles/" + class_
        else:
            relative_path = "../concepts/" + class_
        outstring_insert += "LOAD DATA LOCAL INFILE \'" +  relative_path + ".txt\' INTO TABLE " + class_ + "\nFIELDS TERMINATED BY ';'\nENCLOSED BY '\"'"+\
        "\nLINES TERMINATED BY '\\n'\nIGNORE 1 LINES;\n\n"


    print(outstring_create)
    print(outstring_insert)
    insf.write(outstring_insert)
    cf.write(outstring_create)
# Out:
# CREATE DATABASE bookDB;
#
# USE bookDB;
#
# CREATE TABLE followedBy(
# 	book_id varchar (255)  primary key,
# 	foreign key (book_id) references Book(book_id));
#
# CREATE TABLE Book(
# 	book_id varchar (255)  primary key,
# 	book_description varchar (255) not null,
# 	title varchar (255) not null,
# 	subtitle varchar (255),
# 	book_label varchar (255) not null);
#
# CREATE TABLE FictionalCity);
#
# CREATE TABLE Award(
# 	award_id varchar (255)  primary key);
#
# CREATE TABLE Mayor(
# 	mayor_label varchar (255) not null,
# 	end_time varchar (255),
# 	official_residence varchar (255) not null,
# 	mayor_description varchar (255) not null,
# 	start_time varchar (255) not null,
# 	mayor_id varchar (255)  primary key);
#
# CREATE TABLE Author(
# 	sex varchar (255) not null,
# 	human_id varchar (255)  primary key,
# 	human_label varchar (255) not null,
# 	human_description varchar (255) not null,
# 	DoD varchar (255),
# 	name varchar (255) not null,
# 	DoB varchar (255) not null);
#
# CREATE TABLE Language(
# 	language_id varchar (255)  primary key,
# 	num_speakers varchar (255),
# 	language_description varchar (255) not null,
# 	language_label varchar (255) not null);
#
# CREATE TABLE hasCityLocation(
# 	book_id varchar (255)  primary key,
# 	foreign key (book_id) references Book(book_id),
# 	city_id varchar (255)  primary key,
# 	foreign key (city_id) references City(city_id));
#
# CREATE TABLE hasCharacter(
# 	book_id varchar (255)  primary key,
# 	foreign key (book_id) references Book(book_id),
# 	character_id varchar (255)  primary key,
# 	foreign key (character_id) references Character(character_id));
#
# CREATE TABLE hasEdition(
# 	book_id varchar (255)  primary key,
# 	foreign key (book_id) references Book(book_id),
# 	edition_id varchar (255)  primary key,
# 	foreign key (edition_id) references Edition(edition_id));
#
# CREATE TABLE Translator(
# 	sex varchar (255) not null,
# 	human_id varchar (255)  primary key,
# 	human_label varchar (255) not null,
# 	human_description varchar (255) not null,
# 	DoD varchar (255),
# 	name varchar (255) not null,
# 	DoB varchar (255) not null);
#
# CREATE TABLE hasTranslator(
# 	translator_id varchar (255)  primary key,
# 	foreign key (translator_id) references Translator(translator_id),
# 	edition_id varchar (255)  primary key,
# 	foreign key (edition_id) references Edition(edition_id));
#
# CREATE TABLE hasForewordAuthor(
# 	book_id varchar (255)  primary key,
# 	foreign key (book_id) references Book(book_id),
# 	author_id varchar (255)  primary key,
# 	foreign key (author_id) references Author(author_id));
#
# CREATE TABLE hasCountry(
# 	country_id varchar (255)  primary key,
# 	foreign key (country_id) references Country(country_id),
# 	realcity_id varchar (255)  primary key,
# 	foreign key (realcity_id) references RealCity(realcity_id));
#
# CREATE TABLE PlaceOfBirth(
# 	human_id varchar (255)  primary key,
# 	foreign key (human_id) references Human(human_id),
# 	realcity_id varchar (255)  primary key,
# 	foreign key (realcity_id) references RealCity(realcity_id));
#
# CREATE TABLE hasIllustrator(
# 	human_id varchar (255)  primary key,
# 	foreign key (human_id) references Human(human_id),
# 	edition_id varchar (255)  primary key,
# 	foreign key (edition_id) references Edition(edition_id));
#
# CREATE TABLE hasUsedLanguage(
# 	country_id varchar (255)  primary key,
# 	foreign key (country_id) references Country(country_id),
# 	language_id varchar (255)  primary key,
# 	foreign key (language_id) references Language(language_id));
#
# CREATE TABLE BookWrittenIn(
# 	book_id varchar (255)  primary key,
# 	foreign key (book_id) references Book(book_id),
# 	language_id varchar (255)  primary key,
# 	foreign key (language_id) references Language(language_id));
#
# CREATE TABLE locatedIn(
# 	publisher_id varchar (255)  primary key,
# 	foreign key (publisher_id) references Publisher(publisher_id),
# 	country_id varchar (255)  primary key,
# 	foreign key (country_id) references Country(country_id));
#
# CREATE TABLE FictionalHuman);
#
# CREATE TABLE Country(
# 	country_id varchar (255)  primary key,
# 	country_label varchar (255) not null,
# 	country_description varchar (255) not null);
#
# CREATE TABLE FictionalCharacter(
# 	character_DoD varchar (255),
# 	character_name varchar (255) not null,
# 	character_label varchar (255) not null,
# 	character_id varchar (255)  primary key,
# 	character_description varchar (255) not null,
# 	character_sex varchar (255) not null,
# 	character_DoB varchar (255) not null);
#
# CREATE TABLE PlaceOfDeath(
# 	human_id varchar (255)  primary key,
# 	foreign key (human_id) references Human(human_id),
# 	realcity_id varchar (255)  primary key,
# 	foreign key (realcity_id) references RealCity(realcity_id));
#
# CREATE TABLE hasRole(
# 	human_id varchar (255)  primary key,
# 	foreign key (human_id) references Human(human_id),
# 	mayor_id varchar (255)  primary key,
# 	foreign key (mayor_id) references Mayor(mayor_id));
#
# CREATE TABLE Publisher(
# 	publisher_id varchar (255)  primary key,
# 	inception varchar (255) not null,
# 	publisher_description varchar (255) not null,
# 	publisher_label varchar (255) not null);
#
# CREATE TABLE Edition(
# 	edition_description varchar (255) not null,
# 	edition_label varchar (255) not null,
# 	edition_id varchar (255)  primary key);
#
# CREATE TABLE hasAnalog(
# 	fictionalcity_id varchar (255)  primary key,
# 	foreign key (fictionalcity_id) references FictionalCity(fictionalcity_id),
# 	realcity_id varchar (255)  primary key,
# 	foreign key (realcity_id) references RealCity(realcity_id));
#
# CREATE TABLE City(
# 	city_label varchar (255) not null,
# 	city_id varchar (255)  primary key,
# 	city_description varchar (255) not null);
#
# CREATE TABLE Character(
# 	character_DoD varchar (255),
# 	character_name varchar (255) not null,
# 	character_label varchar (255) not null,
# 	character_id varchar (255)  primary key,
# 	character_description varchar (255) not null,
# 	character_sex varchar (255) not null,
# 	character_DoB varchar (255) not null);
#
# CREATE TABLE hasAfterwordAuthor(
# 	book_id varchar (255)  primary key,
# 	foreign key (book_id) references Book(book_id),
# 	author_id varchar (255)  primary key,
# 	foreign key (author_id) references Author(author_id));
#
# CREATE TABLE InfluencedBy(
# 	author_id varchar (255)  primary key,
# 	foreign key (author_id) references Author(author_id));
#
# CREATE TABLE hasAward(
# 	author_id varchar (255)  primary key,
# 	foreign key (author_id) references Author(author_id),
# 	award_id varchar (255)  primary key,
# 	foreign key (award_id) references Award(award_id));
#
# CREATE TABLE hasPublisher(
# 	publisher_id varchar (255)  primary key,
# 	foreign key (publisher_id) references Publisher(publisher_id),
# 	edition_id varchar (255)  primary key,
# 	foreign key (edition_id) references Edition(edition_id));
#
# CREATE TABLE hasMayor(
# 	realcity_id varchar (255)  primary key,
# 	foreign key (realcity_id) references RealCity(realcity_id),
# 	mayor_id varchar (255)  primary key,
# 	foreign key (mayor_id) references Mayor(mayor_id));
#
# CREATE TABLE hasAuthor_Genre(
# 	author_genre_id varchar (255)  primary key,
# 	foreign key (author_genre_id) references Author_Genre(author_genre_id),
# 	author_id varchar (255)  primary key,
# 	foreign key (author_id) references Author(author_id));
#
# CREATE TABLE hasCountryLocation(
# 	book_id varchar (255)  primary key,
# 	foreign key (book_id) references Book(book_id),
# 	country_id varchar (255)  primary key,
# 	foreign key (country_id) references Country(country_id));
#
# CREATE TABLE RealCity(
# 	population varchar (255),
# 	area varchar (255));
#
# CREATE TABLE hasAuthor(
# 	book_id varchar (255)  primary key,
# 	foreign key (book_id) references Book(book_id),
# 	author_id varchar (255)  primary key,
# 	foreign key (author_id) references Author(author_id));
#
# CREATE TABLE speaks(
# 	language_id varchar (255)  primary key,
# 	foreign key (language_id) references Language(language_id),
# 	translator_id varchar (255)  primary key,
# 	foreign key (translator_id) references Translator(translator_id));
#
# CREATE TABLE Human(
# 	sex varchar (255) not null,
# 	human_id varchar (255)  primary key,
# 	human_label varchar (255) not null,
# 	human_description varchar (255) not null,
# 	DoD varchar (255),
# 	name varchar (255) not null,
# 	DoB varchar (255) not null);
#
# CREATE TABLE FictionalNotHuman);
#
# CREATE TABLE foundedBy(
# 	publisher_id varchar (255)  primary key,
# 	foreign key (publisher_id) references Publisher(publisher_id),
# 	human_id varchar (255)  primary key,
# 	foreign key (human_id) references Human(human_id));
#
# CREATE TABLE Author_Genre(
# 	author_genre_id varchar (255)  primary key);
#
#
# LOAD DATA LOCAL INFILE '../roles/followedBy.txt' INTO TABLE followedBy
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../concepts/Book.txt' INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../concepts/FictionalCity.txt' INTO TABLE FictionalCity
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../concepts/Award.txt' INTO TABLE Award
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../concepts/Mayor.txt' INTO TABLE Mayor
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../concepts/Author.txt' INTO TABLE Author
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../concepts/Language.txt' INTO TABLE Language
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/hasCityLocation.txt' INTO TABLE hasCityLocation
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/hasCharacter.txt' INTO TABLE hasCharacter
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/hasEdition.txt' INTO TABLE hasEdition
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../concepts/Translator.txt' INTO TABLE Translator
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/hasTranslator.txt' INTO TABLE hasTranslator
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/hasForewordAuthor.txt' INTO TABLE hasForewordAuthor
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/hasCountry.txt' INTO TABLE hasCountry
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/PlaceOfBirth.txt' INTO TABLE PlaceOfBirth
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/hasIllustrator.txt' INTO TABLE hasIllustrator
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/hasUsedLanguage.txt' INTO TABLE hasUsedLanguage
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/BookWrittenIn.txt' INTO TABLE BookWrittenIn
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/locatedIn.txt' INTO TABLE locatedIn
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../concepts/FictionalHuman.txt' INTO TABLE FictionalHuman
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../concepts/Country.txt' INTO TABLE Country
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../concepts/FictionalCharacter.txt' INTO TABLE FictionalCharacter
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/PlaceOfDeath.txt' INTO TABLE PlaceOfDeath
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/hasRole.txt' INTO TABLE hasRole
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../concepts/Publisher.txt' INTO TABLE Publisher
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../concepts/Edition.txt' INTO TABLE Edition
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/hasAnalog.txt' INTO TABLE hasAnalog
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../concepts/City.txt' INTO TABLE City
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../concepts/Character.txt' INTO TABLE Character
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/hasAfterwordAuthor.txt' INTO TABLE hasAfterwordAuthor
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/InfluencedBy.txt' INTO TABLE InfluencedBy
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/hasAward.txt' INTO TABLE hasAward
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/hasPublisher.txt' INTO TABLE hasPublisher
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/hasMayor.txt' INTO TABLE hasMayor
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/hasAuthor_Genre.txt' INTO TABLE hasAuthor_Genre
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/hasCountryLocation.txt' INTO TABLE hasCountryLocation
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../concepts/RealCity.txt' INTO TABLE RealCity
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/hasAuthor.txt' INTO TABLE hasAuthor
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/speaks.txt' INTO TABLE speaks
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../concepts/Human.txt' INTO TABLE Human
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../concepts/FictionalNotHuman.txt' INTO TABLE FictionalNotHuman
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../roles/foundedBy.txt' INTO TABLE foundedBy
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE '../concepts/Author_Genre.txt' INTO TABLE Author_Genre
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;

# %%
base_iri = "https://www.wikidata.org/wiki/"
outstring_mappings = "<?xml version=\"1.0\" encoding=\"UTF-8\"?>\n" + \
"<OBDA version=\"1.0\">\n" + \
    "<dataSource databaseDriver=\"org.postgresql.Driver\" databaseName=\"\"\n"+\
        "databasePassword=\"postgres\"\n"+\
        "databaseURL=\"jdbc:postgresql://localhost/comics_db\"\n"+\
        "databaseUsername=\"postgres\" name=\"datasource\"/>\n"+\
    "<prefixes>\n"+\
        "<prefix name=\"owl:\" namespace=\"http://www.w3.org/2002/07/owl#\"/>\n"+\
        "<prefix name=\"rdf:\" namespace=\"http://www.w3.org/1999/02/22-rdf-syntax-ns#\"/>\n"+\
        "<prefix name=\"sh:\" namespace=\"" + base_iri + "/#>\n"+\
        "<prefix name=\"xsd:\" namespace=\"http://www.w3.org/2001/XMLSchema#\"/>\n"+\
        "<prefix name=\":\" namespace=\"" + base_iri + ">\n"+\
        "<prefix name=\"xml:\" namespace=\"http://www.w3.org/XML/1998/namespace\"/>\n"+\
        "<prefix name=\"rdfs:\" namespace=\"http://www.w3.org/2000/01/rdf-schema#\"/>\n"+\
    "</prefixes>\n"

with open("book_mappings.xml", "w") as mapf:
    
    '''#templates
    outstring_mappings += "<templates>\n"
    for class_ in dict_classes.keys():
        outstring_mappings += "<template>http://books/" + class_.lower() + "_{_}</template>\n"
    outstring_mappings += "</templates>\n"'''
    
    outstring_mappings += "<templates>\n<template>https://www.wikidata.org/wiki/{_}</template>\n<template>{_}</template>\n</templates>\n"
    
    #mappings, sql included
    outstring_mappings += "<mappings>\n"
    mapping_counter = 0
    for class_ in dict_classes.keys():
        mapping_counter += 1
        attributes_set = set()
        from_relation = False
        for attribute in dict_classes[class_]["attributes"]:
            attributes_set.add(attribute)
            if "references" in (dict_classes[class_]["attributes"][attribute]).keys():
                from_relation = True
        if from_relation:
            word = "role"
            domain = "DOM"
            range_ = "RANGE"
        else:
            word = "concept"
        query = "SELECT "
        head_string = "\n<HEAD string=\"" + class_ + "_view("
        for attr in attributes_set:
            query += class_[0].lower() + "." + attr + " AS " + attr + ", "
            head_string += attr + ", "
        head_string = head_string[:-2]
        head_string += ")\"/>"
        query = query[:-2]
        query += " FROM book_db." + class_ + " " + class_[0].lower()
        outstring_mappings += "\n<ontologyPredicateMapping id=\"M" + str(mapping_counter) + "_" + class_ + "\">" + \
        "\n<" + word + " string=" + class_ + ">"
        if not from_relation:
            outstring_mappings += "\n<template>" + base_iri + "{" + class_.lower() + "_id}" + "</template>"
        else:
            outstring_mappings += "\n<domainTemplate>" + base_iri + "{" + domain + "_id}" + "</domainTemplate>\n<rangeTemplate>" + base_iri + base_iri + range_ + "{" + range_ + "_id}" + "</rangeTemplate>"
        outstring_mappings += "\n</" + word + ">"
        outstring_mappings += head_string + "\n</ontologyPredicateMapping>\n"
        
        for attr in attributes_set:
            mapping_counter += 1
            outstring_mappings += "\n<ontologyPredicateMapping id=\"M" + str(mapping_counter) + "_" + attr + "\">" + \
            "\n<" + "attribute" + " string=" + class_ + ">"
            outstring_mappings += "\n<domainTemplate>" + base_iri  + "{" + class_.lower() + "_id}" + "</domainTemplate>"
            outstring_mappings += "\n<rangeVariable>" + attr + "</rangeVariable> "+ "\n</" + word + ">"
            outstring_mappings += head_string + "\n</ontologyPredicateMapping>\n"
        
        outstring_mappings += "\n<primitiveView>" + "\n<HEAD string=\"" + class_ + "_view(" + class_ + "_id)\"/>" 
        outstring_mappings += "\n<SQLQuery> " + query + " </SQLQuery>\n</primitiveView>\n"
    outstring_mappings += "\n</mappings>\n<blocks/>\n<constraints/>\n</OBDA>"

    print (outstring_mappings)
    mapf.write(outstring_mappings)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <OBDA version="1.0">
# <dataSource databaseDriver="org.postgresql.Driver" databaseName=""
# databasePassword="postgres"
# databaseURL="jdbc:postgresql://localhost/comics_db"
# databaseUsername="postgres" name="datasource"/>
# <prefixes>
# <prefix name="owl:" namespace="http://www.w3.org/2002/07/owl#"/>
# <prefix name="rdf:" namespace="http://www.w3.org/1999/02/22-rdf-syntax-ns#"/>
# <prefix name="sh:" namespace="https://www.wikidata.org/wiki//#>
# <prefix name="xsd:" namespace="http://www.w3.org/2001/XMLSchema#"/>
# <prefix name=":" namespace="https://www.wikidata.org/wiki/>
# <prefix name="xml:" namespace="http://www.w3.org/XML/1998/namespace"/>
# <prefix name="rdfs:" namespace="http://www.w3.org/2000/01/rdf-schema#"/>
# </prefixes>
# <templates>
# <template>https://www.wikidata.org/wiki/{_}</template>
# <template>{_}</template>
# </templates>
# <mappings>
#
# <ontologyPredicateMapping id="M1_followedBy">
# <role string=followedBy>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="followedBy_view(book_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M2_book_id">
# <attribute string=followedBy>
# <domainTemplate>https://www.wikidata.org/wiki/{followedby_id}</domainTemplate>
# <rangeVariable>book_id</rangeVariable>
# </role>
# <HEAD string="followedBy_view(book_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="followedBy_view(followedBy_id)"/>
# <SQLQuery> SELECT f.book_id AS book_id FROM book_db.followedBy f </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M3_Book">
# <concept string=Book>
# <template>https://www.wikidata.org/wiki/{book_id}</template>
# </concept>
# <HEAD string="Book_view(book_id, book_description, title, subtitle, book_label)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M4_book_id">
# <attribute string=Book>
# <domainTemplate>https://www.wikidata.org/wiki/{book_id}</domainTemplate>
# <rangeVariable>book_id</rangeVariable>
# </concept>
# <HEAD string="Book_view(book_id, book_description, title, subtitle, book_label)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M5_book_description">
# <attribute string=Book>
# <domainTemplate>https://www.wikidata.org/wiki/{book_id}</domainTemplate>
# <rangeVariable>book_description</rangeVariable>
# </concept>
# <HEAD string="Book_view(book_id, book_description, title, subtitle, book_label)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M6_title">
# <attribute string=Book>
# <domainTemplate>https://www.wikidata.org/wiki/{book_id}</domainTemplate>
# <rangeVariable>title</rangeVariable>
# </concept>
# <HEAD string="Book_view(book_id, book_description, title, subtitle, book_label)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M7_subtitle">
# <attribute string=Book>
# <domainTemplate>https://www.wikidata.org/wiki/{book_id}</domainTemplate>
# <rangeVariable>subtitle</rangeVariable>
# </concept>
# <HEAD string="Book_view(book_id, book_description, title, subtitle, book_label)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M8_book_label">
# <attribute string=Book>
# <domainTemplate>https://www.wikidata.org/wiki/{book_id}</domainTemplate>
# <rangeVariable>book_label</rangeVariable>
# </concept>
# <HEAD string="Book_view(book_id, book_description, title, subtitle, book_label)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="Book_view(Book_id)"/>
# <SQLQuery> SELECT b.book_id AS book_id, b.book_description AS book_description, b.title AS title, b.subtitle AS subtitle, b.book_label AS book_label FROM book_db.Book b </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M9_FictionalCity">
# <concept string=FictionalCity>
# <template>https://www.wikidata.org/wiki/{fictionalcity_id}</template>
# </concept>
# <HEAD string="FictionalCity_vie)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="FictionalCity_view(FictionalCity_id)"/>
# <SQLQuery> SELEC FROM book_db.FictionalCity f </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M10_Award">
# <concept string=Award>
# <template>https://www.wikidata.org/wiki/{award_id}</template>
# </concept>
# <HEAD string="Award_view(award_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M11_award_id">
# <attribute string=Award>
# <domainTemplate>https://www.wikidata.org/wiki/{award_id}</domainTemplate>
# <rangeVariable>award_id</rangeVariable>
# </concept>
# <HEAD string="Award_view(award_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="Award_view(Award_id)"/>
# <SQLQuery> SELECT a.award_id AS award_id FROM book_db.Award a </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M12_Mayor">
# <concept string=Mayor>
# <template>https://www.wikidata.org/wiki/{mayor_id}</template>
# </concept>
# <HEAD string="Mayor_view(mayor_description, start_time, mayor_id, mayor_label, end_time, official_residence)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M13_mayor_description">
# <attribute string=Mayor>
# <domainTemplate>https://www.wikidata.org/wiki/{mayor_id}</domainTemplate>
# <rangeVariable>mayor_description</rangeVariable>
# </concept>
# <HEAD string="Mayor_view(mayor_description, start_time, mayor_id, mayor_label, end_time, official_residence)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M14_start_time">
# <attribute string=Mayor>
# <domainTemplate>https://www.wikidata.org/wiki/{mayor_id}</domainTemplate>
# <rangeVariable>start_time</rangeVariable>
# </concept>
# <HEAD string="Mayor_view(mayor_description, start_time, mayor_id, mayor_label, end_time, official_residence)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M15_mayor_id">
# <attribute string=Mayor>
# <domainTemplate>https://www.wikidata.org/wiki/{mayor_id}</domainTemplate>
# <rangeVariable>mayor_id</rangeVariable>
# </concept>
# <HEAD string="Mayor_view(mayor_description, start_time, mayor_id, mayor_label, end_time, official_residence)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M16_mayor_label">
# <attribute string=Mayor>
# <domainTemplate>https://www.wikidata.org/wiki/{mayor_id}</domainTemplate>
# <rangeVariable>mayor_label</rangeVariable>
# </concept>
# <HEAD string="Mayor_view(mayor_description, start_time, mayor_id, mayor_label, end_time, official_residence)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M17_end_time">
# <attribute string=Mayor>
# <domainTemplate>https://www.wikidata.org/wiki/{mayor_id}</domainTemplate>
# <rangeVariable>end_time</rangeVariable>
# </concept>
# <HEAD string="Mayor_view(mayor_description, start_time, mayor_id, mayor_label, end_time, official_residence)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M18_official_residence">
# <attribute string=Mayor>
# <domainTemplate>https://www.wikidata.org/wiki/{mayor_id}</domainTemplate>
# <rangeVariable>official_residence</rangeVariable>
# </concept>
# <HEAD string="Mayor_view(mayor_description, start_time, mayor_id, mayor_label, end_time, official_residence)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="Mayor_view(Mayor_id)"/>
# <SQLQuery> SELECT m.mayor_description AS mayor_description, m.start_time AS start_time, m.mayor_id AS mayor_id, m.mayor_label AS mayor_label, m.end_time AS end_time, m.official_residence AS official_residence FROM book_db.Mayor m </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M19_Author">
# <concept string=Author>
# <template>https://www.wikidata.org/wiki/{author_id}</template>
# </concept>
# <HEAD string="Author_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M20_human_id">
# <attribute string=Author>
# <domainTemplate>https://www.wikidata.org/wiki/{author_id}</domainTemplate>
# <rangeVariable>human_id</rangeVariable>
# </concept>
# <HEAD string="Author_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M21_human_label">
# <attribute string=Author>
# <domainTemplate>https://www.wikidata.org/wiki/{author_id}</domainTemplate>
# <rangeVariable>human_label</rangeVariable>
# </concept>
# <HEAD string="Author_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M22_name">
# <attribute string=Author>
# <domainTemplate>https://www.wikidata.org/wiki/{author_id}</domainTemplate>
# <rangeVariable>name</rangeVariable>
# </concept>
# <HEAD string="Author_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M23_sex">
# <attribute string=Author>
# <domainTemplate>https://www.wikidata.org/wiki/{author_id}</domainTemplate>
# <rangeVariable>sex</rangeVariable>
# </concept>
# <HEAD string="Author_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M24_DoD">
# <attribute string=Author>
# <domainTemplate>https://www.wikidata.org/wiki/{author_id}</domainTemplate>
# <rangeVariable>DoD</rangeVariable>
# </concept>
# <HEAD string="Author_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M25_human_description">
# <attribute string=Author>
# <domainTemplate>https://www.wikidata.org/wiki/{author_id}</domainTemplate>
# <rangeVariable>human_description</rangeVariable>
# </concept>
# <HEAD string="Author_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M26_DoB">
# <attribute string=Author>
# <domainTemplate>https://www.wikidata.org/wiki/{author_id}</domainTemplate>
# <rangeVariable>DoB</rangeVariable>
# </concept>
# <HEAD string="Author_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="Author_view(Author_id)"/>
# <SQLQuery> SELECT a.human_id AS human_id, a.human_label AS human_label, a.name AS name, a.sex AS sex, a.DoD AS DoD, a.human_description AS human_description, a.DoB AS DoB FROM book_db.Author a </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M27_Language">
# <concept string=Language>
# <template>https://www.wikidata.org/wiki/{language_id}</template>
# </concept>
# <HEAD string="Language_view(language_id, num_speakers, language_description, language_label)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M28_language_id">
# <attribute string=Language>
# <domainTemplate>https://www.wikidata.org/wiki/{language_id}</domainTemplate>
# <rangeVariable>language_id</rangeVariable>
# </concept>
# <HEAD string="Language_view(language_id, num_speakers, language_description, language_label)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M29_num_speakers">
# <attribute string=Language>
# <domainTemplate>https://www.wikidata.org/wiki/{language_id}</domainTemplate>
# <rangeVariable>num_speakers</rangeVariable>
# </concept>
# <HEAD string="Language_view(language_id, num_speakers, language_description, language_label)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M30_language_description">
# <attribute string=Language>
# <domainTemplate>https://www.wikidata.org/wiki/{language_id}</domainTemplate>
# <rangeVariable>language_description</rangeVariable>
# </concept>
# <HEAD string="Language_view(language_id, num_speakers, language_description, language_label)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M31_language_label">
# <attribute string=Language>
# <domainTemplate>https://www.wikidata.org/wiki/{language_id}</domainTemplate>
# <rangeVariable>language_label</rangeVariable>
# </concept>
# <HEAD string="Language_view(language_id, num_speakers, language_description, language_label)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="Language_view(Language_id)"/>
# <SQLQuery> SELECT l.language_id AS language_id, l.num_speakers AS num_speakers, l.language_description AS language_description, l.language_label AS language_label FROM book_db.Language l </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M32_hasCityLocation">
# <role string=hasCityLocation>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="hasCityLocation_view(book_id, city_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M33_book_id">
# <attribute string=hasCityLocation>
# <domainTemplate>https://www.wikidata.org/wiki/{hascitylocation_id}</domainTemplate>
# <rangeVariable>book_id</rangeVariable>
# </role>
# <HEAD string="hasCityLocation_view(book_id, city_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M34_city_id">
# <attribute string=hasCityLocation>
# <domainTemplate>https://www.wikidata.org/wiki/{hascitylocation_id}</domainTemplate>
# <rangeVariable>city_id</rangeVariable>
# </role>
# <HEAD string="hasCityLocation_view(book_id, city_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="hasCityLocation_view(hasCityLocation_id)"/>
# <SQLQuery> SELECT h.book_id AS book_id, h.city_id AS city_id FROM book_db.hasCityLocation h </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M35_hasCharacter">
# <role string=hasCharacter>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="hasCharacter_view(book_id, character_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M36_book_id">
# <attribute string=hasCharacter>
# <domainTemplate>https://www.wikidata.org/wiki/{hascharacter_id}</domainTemplate>
# <rangeVariable>book_id</rangeVariable>
# </role>
# <HEAD string="hasCharacter_view(book_id, character_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M37_character_id">
# <attribute string=hasCharacter>
# <domainTemplate>https://www.wikidata.org/wiki/{hascharacter_id}</domainTemplate>
# <rangeVariable>character_id</rangeVariable>
# </role>
# <HEAD string="hasCharacter_view(book_id, character_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="hasCharacter_view(hasCharacter_id)"/>
# <SQLQuery> SELECT h.book_id AS book_id, h.character_id AS character_id FROM book_db.hasCharacter h </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M38_hasEdition">
# <role string=hasEdition>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="hasEdition_view(book_id, edition_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M39_book_id">
# <attribute string=hasEdition>
# <domainTemplate>https://www.wikidata.org/wiki/{hasedition_id}</domainTemplate>
# <rangeVariable>book_id</rangeVariable>
# </role>
# <HEAD string="hasEdition_view(book_id, edition_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M40_edition_id">
# <attribute string=hasEdition>
# <domainTemplate>https://www.wikidata.org/wiki/{hasedition_id}</domainTemplate>
# <rangeVariable>edition_id</rangeVariable>
# </role>
# <HEAD string="hasEdition_view(book_id, edition_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="hasEdition_view(hasEdition_id)"/>
# <SQLQuery> SELECT h.book_id AS book_id, h.edition_id AS edition_id FROM book_db.hasEdition h </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M41_Translator">
# <concept string=Translator>
# <template>https://www.wikidata.org/wiki/{translator_id}</template>
# </concept>
# <HEAD string="Translator_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M42_human_id">
# <attribute string=Translator>
# <domainTemplate>https://www.wikidata.org/wiki/{translator_id}</domainTemplate>
# <rangeVariable>human_id</rangeVariable>
# </concept>
# <HEAD string="Translator_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M43_human_label">
# <attribute string=Translator>
# <domainTemplate>https://www.wikidata.org/wiki/{translator_id}</domainTemplate>
# <rangeVariable>human_label</rangeVariable>
# </concept>
# <HEAD string="Translator_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M44_name">
# <attribute string=Translator>
# <domainTemplate>https://www.wikidata.org/wiki/{translator_id}</domainTemplate>
# <rangeVariable>name</rangeVariable>
# </concept>
# <HEAD string="Translator_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M45_sex">
# <attribute string=Translator>
# <domainTemplate>https://www.wikidata.org/wiki/{translator_id}</domainTemplate>
# <rangeVariable>sex</rangeVariable>
# </concept>
# <HEAD string="Translator_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M46_DoD">
# <attribute string=Translator>
# <domainTemplate>https://www.wikidata.org/wiki/{translator_id}</domainTemplate>
# <rangeVariable>DoD</rangeVariable>
# </concept>
# <HEAD string="Translator_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M47_human_description">
# <attribute string=Translator>
# <domainTemplate>https://www.wikidata.org/wiki/{translator_id}</domainTemplate>
# <rangeVariable>human_description</rangeVariable>
# </concept>
# <HEAD string="Translator_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M48_DoB">
# <attribute string=Translator>
# <domainTemplate>https://www.wikidata.org/wiki/{translator_id}</domainTemplate>
# <rangeVariable>DoB</rangeVariable>
# </concept>
# <HEAD string="Translator_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="Translator_view(Translator_id)"/>
# <SQLQuery> SELECT t.human_id AS human_id, t.human_label AS human_label, t.name AS name, t.sex AS sex, t.DoD AS DoD, t.human_description AS human_description, t.DoB AS DoB FROM book_db.Translator t </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M49_hasTranslator">
# <role string=hasTranslator>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="hasTranslator_view(translator_id, edition_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M50_translator_id">
# <attribute string=hasTranslator>
# <domainTemplate>https://www.wikidata.org/wiki/{hastranslator_id}</domainTemplate>
# <rangeVariable>translator_id</rangeVariable>
# </role>
# <HEAD string="hasTranslator_view(translator_id, edition_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M51_edition_id">
# <attribute string=hasTranslator>
# <domainTemplate>https://www.wikidata.org/wiki/{hastranslator_id}</domainTemplate>
# <rangeVariable>edition_id</rangeVariable>
# </role>
# <HEAD string="hasTranslator_view(translator_id, edition_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="hasTranslator_view(hasTranslator_id)"/>
# <SQLQuery> SELECT h.translator_id AS translator_id, h.edition_id AS edition_id FROM book_db.hasTranslator h </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M52_hasForewordAuthor">
# <role string=hasForewordAuthor>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="hasForewordAuthor_view(book_id, author_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M53_book_id">
# <attribute string=hasForewordAuthor>
# <domainTemplate>https://www.wikidata.org/wiki/{hasforewordauthor_id}</domainTemplate>
# <rangeVariable>book_id</rangeVariable>
# </role>
# <HEAD string="hasForewordAuthor_view(book_id, author_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M54_author_id">
# <attribute string=hasForewordAuthor>
# <domainTemplate>https://www.wikidata.org/wiki/{hasforewordauthor_id}</domainTemplate>
# <rangeVariable>author_id</rangeVariable>
# </role>
# <HEAD string="hasForewordAuthor_view(book_id, author_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="hasForewordAuthor_view(hasForewordAuthor_id)"/>
# <SQLQuery> SELECT h.book_id AS book_id, h.author_id AS author_id FROM book_db.hasForewordAuthor h </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M55_hasCountry">
# <role string=hasCountry>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="hasCountry_view(country_id, realcity_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M56_country_id">
# <attribute string=hasCountry>
# <domainTemplate>https://www.wikidata.org/wiki/{hascountry_id}</domainTemplate>
# <rangeVariable>country_id</rangeVariable>
# </role>
# <HEAD string="hasCountry_view(country_id, realcity_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M57_realcity_id">
# <attribute string=hasCountry>
# <domainTemplate>https://www.wikidata.org/wiki/{hascountry_id}</domainTemplate>
# <rangeVariable>realcity_id</rangeVariable>
# </role>
# <HEAD string="hasCountry_view(country_id, realcity_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="hasCountry_view(hasCountry_id)"/>
# <SQLQuery> SELECT h.country_id AS country_id, h.realcity_id AS realcity_id FROM book_db.hasCountry h </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M58_PlaceOfBirth">
# <role string=PlaceOfBirth>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="PlaceOfBirth_view(human_id, realcity_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M59_human_id">
# <attribute string=PlaceOfBirth>
# <domainTemplate>https://www.wikidata.org/wiki/{placeofbirth_id}</domainTemplate>
# <rangeVariable>human_id</rangeVariable>
# </role>
# <HEAD string="PlaceOfBirth_view(human_id, realcity_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M60_realcity_id">
# <attribute string=PlaceOfBirth>
# <domainTemplate>https://www.wikidata.org/wiki/{placeofbirth_id}</domainTemplate>
# <rangeVariable>realcity_id</rangeVariable>
# </role>
# <HEAD string="PlaceOfBirth_view(human_id, realcity_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="PlaceOfBirth_view(PlaceOfBirth_id)"/>
# <SQLQuery> SELECT p.human_id AS human_id, p.realcity_id AS realcity_id FROM book_db.PlaceOfBirth p </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M61_hasIllustrator">
# <role string=hasIllustrator>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="hasIllustrator_view(human_id, edition_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M62_human_id">
# <attribute string=hasIllustrator>
# <domainTemplate>https://www.wikidata.org/wiki/{hasillustrator_id}</domainTemplate>
# <rangeVariable>human_id</rangeVariable>
# </role>
# <HEAD string="hasIllustrator_view(human_id, edition_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M63_edition_id">
# <attribute string=hasIllustrator>
# <domainTemplate>https://www.wikidata.org/wiki/{hasillustrator_id}</domainTemplate>
# <rangeVariable>edition_id</rangeVariable>
# </role>
# <HEAD string="hasIllustrator_view(human_id, edition_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="hasIllustrator_view(hasIllustrator_id)"/>
# <SQLQuery> SELECT h.human_id AS human_id, h.edition_id AS edition_id FROM book_db.hasIllustrator h </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M64_hasUsedLanguage">
# <role string=hasUsedLanguage>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="hasUsedLanguage_view(country_id, language_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M65_country_id">
# <attribute string=hasUsedLanguage>
# <domainTemplate>https://www.wikidata.org/wiki/{hasusedlanguage_id}</domainTemplate>
# <rangeVariable>country_id</rangeVariable>
# </role>
# <HEAD string="hasUsedLanguage_view(country_id, language_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M66_language_id">
# <attribute string=hasUsedLanguage>
# <domainTemplate>https://www.wikidata.org/wiki/{hasusedlanguage_id}</domainTemplate>
# <rangeVariable>language_id</rangeVariable>
# </role>
# <HEAD string="hasUsedLanguage_view(country_id, language_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="hasUsedLanguage_view(hasUsedLanguage_id)"/>
# <SQLQuery> SELECT h.country_id AS country_id, h.language_id AS language_id FROM book_db.hasUsedLanguage h </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M67_BookWrittenIn">
# <role string=BookWrittenIn>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="BookWrittenIn_view(book_id, language_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M68_book_id">
# <attribute string=BookWrittenIn>
# <domainTemplate>https://www.wikidata.org/wiki/{bookwrittenin_id}</domainTemplate>
# <rangeVariable>book_id</rangeVariable>
# </role>
# <HEAD string="BookWrittenIn_view(book_id, language_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M69_language_id">
# <attribute string=BookWrittenIn>
# <domainTemplate>https://www.wikidata.org/wiki/{bookwrittenin_id}</domainTemplate>
# <rangeVariable>language_id</rangeVariable>
# </role>
# <HEAD string="BookWrittenIn_view(book_id, language_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="BookWrittenIn_view(BookWrittenIn_id)"/>
# <SQLQuery> SELECT b.book_id AS book_id, b.language_id AS language_id FROM book_db.BookWrittenIn b </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M70_locatedIn">
# <role string=locatedIn>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="locatedIn_view(publisher_id, country_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M71_publisher_id">
# <attribute string=locatedIn>
# <domainTemplate>https://www.wikidata.org/wiki/{locatedin_id}</domainTemplate>
# <rangeVariable>publisher_id</rangeVariable>
# </role>
# <HEAD string="locatedIn_view(publisher_id, country_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M72_country_id">
# <attribute string=locatedIn>
# <domainTemplate>https://www.wikidata.org/wiki/{locatedin_id}</domainTemplate>
# <rangeVariable>country_id</rangeVariable>
# </role>
# <HEAD string="locatedIn_view(publisher_id, country_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="locatedIn_view(locatedIn_id)"/>
# <SQLQuery> SELECT l.publisher_id AS publisher_id, l.country_id AS country_id FROM book_db.locatedIn l </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M73_FictionalHuman">
# <concept string=FictionalHuman>
# <template>https://www.wikidata.org/wiki/{fictionalhuman_id}</template>
# </concept>
# <HEAD string="FictionalHuman_vie)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="FictionalHuman_view(FictionalHuman_id)"/>
# <SQLQuery> SELEC FROM book_db.FictionalHuman f </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M74_Country">
# <concept string=Country>
# <template>https://www.wikidata.org/wiki/{country_id}</template>
# </concept>
# <HEAD string="Country_view(country_id, country_description, country_label)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M75_country_id">
# <attribute string=Country>
# <domainTemplate>https://www.wikidata.org/wiki/{country_id}</domainTemplate>
# <rangeVariable>country_id</rangeVariable>
# </concept>
# <HEAD string="Country_view(country_id, country_description, country_label)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M76_country_description">
# <attribute string=Country>
# <domainTemplate>https://www.wikidata.org/wiki/{country_id}</domainTemplate>
# <rangeVariable>country_description</rangeVariable>
# </concept>
# <HEAD string="Country_view(country_id, country_description, country_label)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M77_country_label">
# <attribute string=Country>
# <domainTemplate>https://www.wikidata.org/wiki/{country_id}</domainTemplate>
# <rangeVariable>country_label</rangeVariable>
# </concept>
# <HEAD string="Country_view(country_id, country_description, country_label)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="Country_view(Country_id)"/>
# <SQLQuery> SELECT c.country_id AS country_id, c.country_description AS country_description, c.country_label AS country_label FROM book_db.Country c </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M78_FictionalCharacter">
# <concept string=FictionalCharacter>
# <template>https://www.wikidata.org/wiki/{fictionalcharacter_id}</template>
# </concept>
# <HEAD string="FictionalCharacter_view(character_label, character_id, character_description, character_sex, character_DoB, character_name, character_DoD)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M79_character_label">
# <attribute string=FictionalCharacter>
# <domainTemplate>https://www.wikidata.org/wiki/{fictionalcharacter_id}</domainTemplate>
# <rangeVariable>character_label</rangeVariable>
# </concept>
# <HEAD string="FictionalCharacter_view(character_label, character_id, character_description, character_sex, character_DoB, character_name, character_DoD)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M80_character_id">
# <attribute string=FictionalCharacter>
# <domainTemplate>https://www.wikidata.org/wiki/{fictionalcharacter_id}</domainTemplate>
# <rangeVariable>character_id</rangeVariable>
# </concept>
# <HEAD string="FictionalCharacter_view(character_label, character_id, character_description, character_sex, character_DoB, character_name, character_DoD)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M81_character_description">
# <attribute string=FictionalCharacter>
# <domainTemplate>https://www.wikidata.org/wiki/{fictionalcharacter_id}</domainTemplate>
# <rangeVariable>character_description</rangeVariable>
# </concept>
# <HEAD string="FictionalCharacter_view(character_label, character_id, character_description, character_sex, character_DoB, character_name, character_DoD)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M82_character_sex">
# <attribute string=FictionalCharacter>
# <domainTemplate>https://www.wikidata.org/wiki/{fictionalcharacter_id}</domainTemplate>
# <rangeVariable>character_sex</rangeVariable>
# </concept>
# <HEAD string="FictionalCharacter_view(character_label, character_id, character_description, character_sex, character_DoB, character_name, character_DoD)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M83_character_DoB">
# <attribute string=FictionalCharacter>
# <domainTemplate>https://www.wikidata.org/wiki/{fictionalcharacter_id}</domainTemplate>
# <rangeVariable>character_DoB</rangeVariable>
# </concept>
# <HEAD string="FictionalCharacter_view(character_label, character_id, character_description, character_sex, character_DoB, character_name, character_DoD)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M84_character_name">
# <attribute string=FictionalCharacter>
# <domainTemplate>https://www.wikidata.org/wiki/{fictionalcharacter_id}</domainTemplate>
# <rangeVariable>character_name</rangeVariable>
# </concept>
# <HEAD string="FictionalCharacter_view(character_label, character_id, character_description, character_sex, character_DoB, character_name, character_DoD)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M85_character_DoD">
# <attribute string=FictionalCharacter>
# <domainTemplate>https://www.wikidata.org/wiki/{fictionalcharacter_id}</domainTemplate>
# <rangeVariable>character_DoD</rangeVariable>
# </concept>
# <HEAD string="FictionalCharacter_view(character_label, character_id, character_description, character_sex, character_DoB, character_name, character_DoD)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="FictionalCharacter_view(FictionalCharacter_id)"/>
# <SQLQuery> SELECT f.character_label AS character_label, f.character_id AS character_id, f.character_description AS character_description, f.character_sex AS character_sex, f.character_DoB AS character_DoB, f.character_name AS character_name, f.character_DoD AS character_DoD FROM book_db.FictionalCharacter f </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M86_PlaceOfDeath">
# <role string=PlaceOfDeath>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="PlaceOfDeath_view(human_id, realcity_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M87_human_id">
# <attribute string=PlaceOfDeath>
# <domainTemplate>https://www.wikidata.org/wiki/{placeofdeath_id}</domainTemplate>
# <rangeVariable>human_id</rangeVariable>
# </role>
# <HEAD string="PlaceOfDeath_view(human_id, realcity_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M88_realcity_id">
# <attribute string=PlaceOfDeath>
# <domainTemplate>https://www.wikidata.org/wiki/{placeofdeath_id}</domainTemplate>
# <rangeVariable>realcity_id</rangeVariable>
# </role>
# <HEAD string="PlaceOfDeath_view(human_id, realcity_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="PlaceOfDeath_view(PlaceOfDeath_id)"/>
# <SQLQuery> SELECT p.human_id AS human_id, p.realcity_id AS realcity_id FROM book_db.PlaceOfDeath p </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M89_hasRole">
# <role string=hasRole>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="hasRole_view(human_id, mayor_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M90_human_id">
# <attribute string=hasRole>
# <domainTemplate>https://www.wikidata.org/wiki/{hasrole_id}</domainTemplate>
# <rangeVariable>human_id</rangeVariable>
# </role>
# <HEAD string="hasRole_view(human_id, mayor_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M91_mayor_id">
# <attribute string=hasRole>
# <domainTemplate>https://www.wikidata.org/wiki/{hasrole_id}</domainTemplate>
# <rangeVariable>mayor_id</rangeVariable>
# </role>
# <HEAD string="hasRole_view(human_id, mayor_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="hasRole_view(hasRole_id)"/>
# <SQLQuery> SELECT h.human_id AS human_id, h.mayor_id AS mayor_id FROM book_db.hasRole h </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M92_Publisher">
# <concept string=Publisher>
# <template>https://www.wikidata.org/wiki/{publisher_id}</template>
# </concept>
# <HEAD string="Publisher_view(publisher_id, publisher_description, publisher_label, inception)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M93_publisher_id">
# <attribute string=Publisher>
# <domainTemplate>https://www.wikidata.org/wiki/{publisher_id}</domainTemplate>
# <rangeVariable>publisher_id</rangeVariable>
# </concept>
# <HEAD string="Publisher_view(publisher_id, publisher_description, publisher_label, inception)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M94_publisher_description">
# <attribute string=Publisher>
# <domainTemplate>https://www.wikidata.org/wiki/{publisher_id}</domainTemplate>
# <rangeVariable>publisher_description</rangeVariable>
# </concept>
# <HEAD string="Publisher_view(publisher_id, publisher_description, publisher_label, inception)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M95_publisher_label">
# <attribute string=Publisher>
# <domainTemplate>https://www.wikidata.org/wiki/{publisher_id}</domainTemplate>
# <rangeVariable>publisher_label</rangeVariable>
# </concept>
# <HEAD string="Publisher_view(publisher_id, publisher_description, publisher_label, inception)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M96_inception">
# <attribute string=Publisher>
# <domainTemplate>https://www.wikidata.org/wiki/{publisher_id}</domainTemplate>
# <rangeVariable>inception</rangeVariable>
# </concept>
# <HEAD string="Publisher_view(publisher_id, publisher_description, publisher_label, inception)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="Publisher_view(Publisher_id)"/>
# <SQLQuery> SELECT p.publisher_id AS publisher_id, p.publisher_description AS publisher_description, p.publisher_label AS publisher_label, p.inception AS inception FROM book_db.Publisher p </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M97_Edition">
# <concept string=Edition>
# <template>https://www.wikidata.org/wiki/{edition_id}</template>
# </concept>
# <HEAD string="Edition_view(edition_description, edition_label, edition_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M98_edition_description">
# <attribute string=Edition>
# <domainTemplate>https://www.wikidata.org/wiki/{edition_id}</domainTemplate>
# <rangeVariable>edition_description</rangeVariable>
# </concept>
# <HEAD string="Edition_view(edition_description, edition_label, edition_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M99_edition_label">
# <attribute string=Edition>
# <domainTemplate>https://www.wikidata.org/wiki/{edition_id}</domainTemplate>
# <rangeVariable>edition_label</rangeVariable>
# </concept>
# <HEAD string="Edition_view(edition_description, edition_label, edition_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M100_edition_id">
# <attribute string=Edition>
# <domainTemplate>https://www.wikidata.org/wiki/{edition_id}</domainTemplate>
# <rangeVariable>edition_id</rangeVariable>
# </concept>
# <HEAD string="Edition_view(edition_description, edition_label, edition_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="Edition_view(Edition_id)"/>
# <SQLQuery> SELECT e.edition_description AS edition_description, e.edition_label AS edition_label, e.edition_id AS edition_id FROM book_db.Edition e </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M101_hasAnalog">
# <role string=hasAnalog>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="hasAnalog_view(fictionalcity_id, realcity_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M102_fictionalcity_id">
# <attribute string=hasAnalog>
# <domainTemplate>https://www.wikidata.org/wiki/{hasanalog_id}</domainTemplate>
# <rangeVariable>fictionalcity_id</rangeVariable>
# </role>
# <HEAD string="hasAnalog_view(fictionalcity_id, realcity_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M103_realcity_id">
# <attribute string=hasAnalog>
# <domainTemplate>https://www.wikidata.org/wiki/{hasanalog_id}</domainTemplate>
# <rangeVariable>realcity_id</rangeVariable>
# </role>
# <HEAD string="hasAnalog_view(fictionalcity_id, realcity_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="hasAnalog_view(hasAnalog_id)"/>
# <SQLQuery> SELECT h.fictionalcity_id AS fictionalcity_id, h.realcity_id AS realcity_id FROM book_db.hasAnalog h </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M104_City">
# <concept string=City>
# <template>https://www.wikidata.org/wiki/{city_id}</template>
# </concept>
# <HEAD string="City_view(city_label, city_id, city_description)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M105_city_label">
# <attribute string=City>
# <domainTemplate>https://www.wikidata.org/wiki/{city_id}</domainTemplate>
# <rangeVariable>city_label</rangeVariable>
# </concept>
# <HEAD string="City_view(city_label, city_id, city_description)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M106_city_id">
# <attribute string=City>
# <domainTemplate>https://www.wikidata.org/wiki/{city_id}</domainTemplate>
# <rangeVariable>city_id</rangeVariable>
# </concept>
# <HEAD string="City_view(city_label, city_id, city_description)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M107_city_description">
# <attribute string=City>
# <domainTemplate>https://www.wikidata.org/wiki/{city_id}</domainTemplate>
# <rangeVariable>city_description</rangeVariable>
# </concept>
# <HEAD string="City_view(city_label, city_id, city_description)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="City_view(City_id)"/>
# <SQLQuery> SELECT c.city_label AS city_label, c.city_id AS city_id, c.city_description AS city_description FROM book_db.City c </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M108_Character">
# <concept string=Character>
# <template>https://www.wikidata.org/wiki/{character_id}</template>
# </concept>
# <HEAD string="Character_view(character_label, character_id, character_description, character_sex, character_DoB, character_name, character_DoD)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M109_character_label">
# <attribute string=Character>
# <domainTemplate>https://www.wikidata.org/wiki/{character_id}</domainTemplate>
# <rangeVariable>character_label</rangeVariable>
# </concept>
# <HEAD string="Character_view(character_label, character_id, character_description, character_sex, character_DoB, character_name, character_DoD)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M110_character_id">
# <attribute string=Character>
# <domainTemplate>https://www.wikidata.org/wiki/{character_id}</domainTemplate>
# <rangeVariable>character_id</rangeVariable>
# </concept>
# <HEAD string="Character_view(character_label, character_id, character_description, character_sex, character_DoB, character_name, character_DoD)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M111_character_description">
# <attribute string=Character>
# <domainTemplate>https://www.wikidata.org/wiki/{character_id}</domainTemplate>
# <rangeVariable>character_description</rangeVariable>
# </concept>
# <HEAD string="Character_view(character_label, character_id, character_description, character_sex, character_DoB, character_name, character_DoD)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M112_character_sex">
# <attribute string=Character>
# <domainTemplate>https://www.wikidata.org/wiki/{character_id}</domainTemplate>
# <rangeVariable>character_sex</rangeVariable>
# </concept>
# <HEAD string="Character_view(character_label, character_id, character_description, character_sex, character_DoB, character_name, character_DoD)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M113_character_DoB">
# <attribute string=Character>
# <domainTemplate>https://www.wikidata.org/wiki/{character_id}</domainTemplate>
# <rangeVariable>character_DoB</rangeVariable>
# </concept>
# <HEAD string="Character_view(character_label, character_id, character_description, character_sex, character_DoB, character_name, character_DoD)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M114_character_name">
# <attribute string=Character>
# <domainTemplate>https://www.wikidata.org/wiki/{character_id}</domainTemplate>
# <rangeVariable>character_name</rangeVariable>
# </concept>
# <HEAD string="Character_view(character_label, character_id, character_description, character_sex, character_DoB, character_name, character_DoD)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M115_character_DoD">
# <attribute string=Character>
# <domainTemplate>https://www.wikidata.org/wiki/{character_id}</domainTemplate>
# <rangeVariable>character_DoD</rangeVariable>
# </concept>
# <HEAD string="Character_view(character_label, character_id, character_description, character_sex, character_DoB, character_name, character_DoD)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="Character_view(Character_id)"/>
# <SQLQuery> SELECT c.character_label AS character_label, c.character_id AS character_id, c.character_description AS character_description, c.character_sex AS character_sex, c.character_DoB AS character_DoB, c.character_name AS character_name, c.character_DoD AS character_DoD FROM book_db.Character c </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M116_hasAfterwordAuthor">
# <role string=hasAfterwordAuthor>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="hasAfterwordAuthor_view(book_id, author_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M117_book_id">
# <attribute string=hasAfterwordAuthor>
# <domainTemplate>https://www.wikidata.org/wiki/{hasafterwordauthor_id}</domainTemplate>
# <rangeVariable>book_id</rangeVariable>
# </role>
# <HEAD string="hasAfterwordAuthor_view(book_id, author_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M118_author_id">
# <attribute string=hasAfterwordAuthor>
# <domainTemplate>https://www.wikidata.org/wiki/{hasafterwordauthor_id}</domainTemplate>
# <rangeVariable>author_id</rangeVariable>
# </role>
# <HEAD string="hasAfterwordAuthor_view(book_id, author_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="hasAfterwordAuthor_view(hasAfterwordAuthor_id)"/>
# <SQLQuery> SELECT h.book_id AS book_id, h.author_id AS author_id FROM book_db.hasAfterwordAuthor h </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M119_InfluencedBy">
# <role string=InfluencedBy>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="InfluencedBy_view(author_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M120_author_id">
# <attribute string=InfluencedBy>
# <domainTemplate>https://www.wikidata.org/wiki/{influencedby_id}</domainTemplate>
# <rangeVariable>author_id</rangeVariable>
# </role>
# <HEAD string="InfluencedBy_view(author_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="InfluencedBy_view(InfluencedBy_id)"/>
# <SQLQuery> SELECT i.author_id AS author_id FROM book_db.InfluencedBy i </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M121_hasAward">
# <role string=hasAward>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="hasAward_view(author_id, award_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M122_author_id">
# <attribute string=hasAward>
# <domainTemplate>https://www.wikidata.org/wiki/{hasaward_id}</domainTemplate>
# <rangeVariable>author_id</rangeVariable>
# </role>
# <HEAD string="hasAward_view(author_id, award_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M123_award_id">
# <attribute string=hasAward>
# <domainTemplate>https://www.wikidata.org/wiki/{hasaward_id}</domainTemplate>
# <rangeVariable>award_id</rangeVariable>
# </role>
# <HEAD string="hasAward_view(author_id, award_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="hasAward_view(hasAward_id)"/>
# <SQLQuery> SELECT h.author_id AS author_id, h.award_id AS award_id FROM book_db.hasAward h </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M124_hasPublisher">
# <role string=hasPublisher>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="hasPublisher_view(publisher_id, edition_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M125_publisher_id">
# <attribute string=hasPublisher>
# <domainTemplate>https://www.wikidata.org/wiki/{haspublisher_id}</domainTemplate>
# <rangeVariable>publisher_id</rangeVariable>
# </role>
# <HEAD string="hasPublisher_view(publisher_id, edition_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M126_edition_id">
# <attribute string=hasPublisher>
# <domainTemplate>https://www.wikidata.org/wiki/{haspublisher_id}</domainTemplate>
# <rangeVariable>edition_id</rangeVariable>
# </role>
# <HEAD string="hasPublisher_view(publisher_id, edition_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="hasPublisher_view(hasPublisher_id)"/>
# <SQLQuery> SELECT h.publisher_id AS publisher_id, h.edition_id AS edition_id FROM book_db.hasPublisher h </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M127_hasMayor">
# <role string=hasMayor>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="hasMayor_view(realcity_id, mayor_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M128_realcity_id">
# <attribute string=hasMayor>
# <domainTemplate>https://www.wikidata.org/wiki/{hasmayor_id}</domainTemplate>
# <rangeVariable>realcity_id</rangeVariable>
# </role>
# <HEAD string="hasMayor_view(realcity_id, mayor_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M129_mayor_id">
# <attribute string=hasMayor>
# <domainTemplate>https://www.wikidata.org/wiki/{hasmayor_id}</domainTemplate>
# <rangeVariable>mayor_id</rangeVariable>
# </role>
# <HEAD string="hasMayor_view(realcity_id, mayor_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="hasMayor_view(hasMayor_id)"/>
# <SQLQuery> SELECT h.realcity_id AS realcity_id, h.mayor_id AS mayor_id FROM book_db.hasMayor h </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M130_hasAuthor_Genre">
# <role string=hasAuthor_Genre>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="hasAuthor_Genre_view(author_genre_id, author_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M131_author_genre_id">
# <attribute string=hasAuthor_Genre>
# <domainTemplate>https://www.wikidata.org/wiki/{hasauthor_genre_id}</domainTemplate>
# <rangeVariable>author_genre_id</rangeVariable>
# </role>
# <HEAD string="hasAuthor_Genre_view(author_genre_id, author_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M132_author_id">
# <attribute string=hasAuthor_Genre>
# <domainTemplate>https://www.wikidata.org/wiki/{hasauthor_genre_id}</domainTemplate>
# <rangeVariable>author_id</rangeVariable>
# </role>
# <HEAD string="hasAuthor_Genre_view(author_genre_id, author_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="hasAuthor_Genre_view(hasAuthor_Genre_id)"/>
# <SQLQuery> SELECT h.author_genre_id AS author_genre_id, h.author_id AS author_id FROM book_db.hasAuthor_Genre h </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M133_hasCountryLocation">
# <role string=hasCountryLocation>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="hasCountryLocation_view(book_id, country_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M134_book_id">
# <attribute string=hasCountryLocation>
# <domainTemplate>https://www.wikidata.org/wiki/{hascountrylocation_id}</domainTemplate>
# <rangeVariable>book_id</rangeVariable>
# </role>
# <HEAD string="hasCountryLocation_view(book_id, country_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M135_country_id">
# <attribute string=hasCountryLocation>
# <domainTemplate>https://www.wikidata.org/wiki/{hascountrylocation_id}</domainTemplate>
# <rangeVariable>country_id</rangeVariable>
# </role>
# <HEAD string="hasCountryLocation_view(book_id, country_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="hasCountryLocation_view(hasCountryLocation_id)"/>
# <SQLQuery> SELECT h.book_id AS book_id, h.country_id AS country_id FROM book_db.hasCountryLocation h </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M136_RealCity">
# <concept string=RealCity>
# <template>https://www.wikidata.org/wiki/{realcity_id}</template>
# </concept>
# <HEAD string="RealCity_view(population, area)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M137_population">
# <attribute string=RealCity>
# <domainTemplate>https://www.wikidata.org/wiki/{realcity_id}</domainTemplate>
# <rangeVariable>population</rangeVariable>
# </concept>
# <HEAD string="RealCity_view(population, area)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M138_area">
# <attribute string=RealCity>
# <domainTemplate>https://www.wikidata.org/wiki/{realcity_id}</domainTemplate>
# <rangeVariable>area</rangeVariable>
# </concept>
# <HEAD string="RealCity_view(population, area)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="RealCity_view(RealCity_id)"/>
# <SQLQuery> SELECT r.population AS population, r.area AS area FROM book_db.RealCity r </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M139_hasAuthor">
# <role string=hasAuthor>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="hasAuthor_view(book_id, author_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M140_book_id">
# <attribute string=hasAuthor>
# <domainTemplate>https://www.wikidata.org/wiki/{hasauthor_id}</domainTemplate>
# <rangeVariable>book_id</rangeVariable>
# </role>
# <HEAD string="hasAuthor_view(book_id, author_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M141_author_id">
# <attribute string=hasAuthor>
# <domainTemplate>https://www.wikidata.org/wiki/{hasauthor_id}</domainTemplate>
# <rangeVariable>author_id</rangeVariable>
# </role>
# <HEAD string="hasAuthor_view(book_id, author_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="hasAuthor_view(hasAuthor_id)"/>
# <SQLQuery> SELECT h.book_id AS book_id, h.author_id AS author_id FROM book_db.hasAuthor h </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M142_speaks">
# <role string=speaks>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="speaks_view(language_id, translator_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M143_language_id">
# <attribute string=speaks>
# <domainTemplate>https://www.wikidata.org/wiki/{speaks_id}</domainTemplate>
# <rangeVariable>language_id</rangeVariable>
# </role>
# <HEAD string="speaks_view(language_id, translator_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M144_translator_id">
# <attribute string=speaks>
# <domainTemplate>https://www.wikidata.org/wiki/{speaks_id}</domainTemplate>
# <rangeVariable>translator_id</rangeVariable>
# </role>
# <HEAD string="speaks_view(language_id, translator_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="speaks_view(speaks_id)"/>
# <SQLQuery> SELECT s.language_id AS language_id, s.translator_id AS translator_id FROM book_db.speaks s </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M145_Human">
# <concept string=Human>
# <template>https://www.wikidata.org/wiki/{human_id}</template>
# </concept>
# <HEAD string="Human_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M146_human_id">
# <attribute string=Human>
# <domainTemplate>https://www.wikidata.org/wiki/{human_id}</domainTemplate>
# <rangeVariable>human_id</rangeVariable>
# </concept>
# <HEAD string="Human_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M147_human_label">
# <attribute string=Human>
# <domainTemplate>https://www.wikidata.org/wiki/{human_id}</domainTemplate>
# <rangeVariable>human_label</rangeVariable>
# </concept>
# <HEAD string="Human_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M148_name">
# <attribute string=Human>
# <domainTemplate>https://www.wikidata.org/wiki/{human_id}</domainTemplate>
# <rangeVariable>name</rangeVariable>
# </concept>
# <HEAD string="Human_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M149_sex">
# <attribute string=Human>
# <domainTemplate>https://www.wikidata.org/wiki/{human_id}</domainTemplate>
# <rangeVariable>sex</rangeVariable>
# </concept>
# <HEAD string="Human_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M150_DoD">
# <attribute string=Human>
# <domainTemplate>https://www.wikidata.org/wiki/{human_id}</domainTemplate>
# <rangeVariable>DoD</rangeVariable>
# </concept>
# <HEAD string="Human_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M151_human_description">
# <attribute string=Human>
# <domainTemplate>https://www.wikidata.org/wiki/{human_id}</domainTemplate>
# <rangeVariable>human_description</rangeVariable>
# </concept>
# <HEAD string="Human_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M152_DoB">
# <attribute string=Human>
# <domainTemplate>https://www.wikidata.org/wiki/{human_id}</domainTemplate>
# <rangeVariable>DoB</rangeVariable>
# </concept>
# <HEAD string="Human_view(human_id, human_label, name, sex, DoD, human_description, DoB)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="Human_view(Human_id)"/>
# <SQLQuery> SELECT h.human_id AS human_id, h.human_label AS human_label, h.name AS name, h.sex AS sex, h.DoD AS DoD, h.human_description AS human_description, h.DoB AS DoB FROM book_db.Human h </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M153_FictionalNotHuman">
# <concept string=FictionalNotHuman>
# <template>https://www.wikidata.org/wiki/{fictionalnothuman_id}</template>
# </concept>
# <HEAD string="FictionalNotHuman_vie)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="FictionalNotHuman_view(FictionalNotHuman_id)"/>
# <SQLQuery> SELEC FROM book_db.FictionalNotHuman f </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M154_foundedBy">
# <role string=foundedBy>
# <domainTemplate>https://www.wikidata.org/wiki/{DOM_id}</domainTemplate>
# <rangeTemplate>https://www.wikidata.org/wiki/https://www.wikidata.org/wiki/RANGE{RANGE_id}</rangeTemplate>
# </role>
# <HEAD string="foundedBy_view(publisher_id, human_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M155_publisher_id">
# <attribute string=foundedBy>
# <domainTemplate>https://www.wikidata.org/wiki/{foundedby_id}</domainTemplate>
# <rangeVariable>publisher_id</rangeVariable>
# </role>
# <HEAD string="foundedBy_view(publisher_id, human_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M156_human_id">
# <attribute string=foundedBy>
# <domainTemplate>https://www.wikidata.org/wiki/{foundedby_id}</domainTemplate>
# <rangeVariable>human_id</rangeVariable>
# </role>
# <HEAD string="foundedBy_view(publisher_id, human_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="foundedBy_view(foundedBy_id)"/>
# <SQLQuery> SELECT f.publisher_id AS publisher_id, f.human_id AS human_id FROM book_db.foundedBy f </SQLQuery>
# </primitiveView>
#
# <ontologyPredicateMapping id="M157_Author_Genre">
# <concept string=Author_Genre>
# <template>https://www.wikidata.org/wiki/{author_genre_id}</template>
# </concept>
# <HEAD string="Author_Genre_view(author_genre_id)"/>
# </ontologyPredicateMapping>
#
# <ontologyPredicateMapping id="M158_author_genre_id">
# <attribute string=Author_Genre>
# <domainTemplate>https://www.wikidata.org/wiki/{author_genre_id}</domainTemplate>
# <rangeVariable>author_genre_id</rangeVariable>
# </concept>
# <HEAD string="Author_Genre_view(author_genre_id)"/>
# </ontologyPredicateMapping>
#
# <primitiveView>
# <HEAD string="Author_Genre_view(Author_Genre_id)"/>
# <SQLQuery> SELECT a.author_genre_id AS author_genre_id FROM book_db.Author_Genre a </SQLQuery>
# </primitiveView>
#
# </mappings>
# <blocks/>
# <constraints/>
# </OBDA>
