# %%
#parser: given owl, set up db and write mappings

# %%
with open ("../books/book_17_06.owl", "r") as fowl:
    content = fowl.read()
    i = 0
    lines = content.split("\n")
    outstring = ""
    dict_classes = {}
    dict_relations = {}
    dict_attributes = {}
    while (i < len(lines)):
        
        line = lines[i]
        if "Prefix" in lines[i]:
            i += 1
            continue

        if "Declaration(Class" in lines[i]: #from now on, work on this class
            classe = line.split("/")[-1][:-3]
            dict_classes[classe] = {}
            dict_classes[classe]["attributes"] = {}
            i += 1
            continue
            
        if "Declaration(ObjectProperty" in lines[i]:
            relation = line.split("/")[-1][:-3]
            dict_relations[relation] = {}
            dict_relations[relation]["functional"] = False
            dict_relations[relation]["inv_functional"] = False
            i += 1
            continue
        
        if "Declaration(DataProperty" in lines[i]:
            attribute = line.split("/")[-1][:-3]
            dict_attributes[attribute] = {}
            dict_attributes[attribute]["functional"] = False
            dict_attributes[attribute]["inv_functional"] = False
            i += 1
            continue
            
        if "ObjectPropertyDomain" in lines[i]:
            relation = line.split(">")[0].split("/")[-1]
            domain = line.split("/")[-1][:-2]
            dict_relations[relation]["domain"] = {}
            dict_relations[relation]["domain"]["name"] = domain
            dict_relations[relation]["domain"]["nullable"] = True
            i += 1
            continue
            
        if "DataPropertyDomain" in lines[i]:
            attribute = line.split(">")[0].split("/")[-1]
            domain = line.split("/")[-1][:-2]
            dict_attributes[attribute]["domain"] = {}
            dict_attributes[attribute]["domain"]["name"] = domain
            dict_attributes[attribute]["domain"]["nullable"] = True
            i += 1
            continue
        
        if "ObjectPropertyRange" in lines[i]:
            relation = lines[i].split(">")[0].split("/")[-1]
            range_ = line.split("/")[-1][:-2]
            dict_relations[relation]["range"] = {}
            dict_relations[relation]["range"]["name"] = range_
            dict_relations[relation]["range"]["nullable"] = True
            i += 1
            continue
            
        if "DataPropertyRange" in lines[i]:
            attribute = lines[i].split(">")[0].split("/")[-1]
            range_ = line.split("/")[-1][:-2]
            dict_attributes[attribute]["range"] = {}
            dict_attributes[attribute]["range"]["name"] = range_
            #dict_attributes[attribute]["range"]["nullable"] = True
            i += 1
            continue
        
        if "FunctionalObjectProperty" in lines[i]:
            relation = lines[i].split("/")[-1][:-2]
            dict_relations[relation]["functional"] = True
            i += 1
            continue
            
        if "FunctionalDataProperty" in lines[i]:
            attribute = line.split("/")[-1][:-2]
            dict_attributes[attribute]["functional"] = True
            i += 1
            continue

        if "EquivalentClasses" in lines[i] and "Thing" in lines[i]:
            relation = line.split(">")[-2].split("/")[-1]
            if "ObjectInverseOf" not in lines[i]:
                domain = line.split(">")[0].split("/")[-1]
                dict_relations[relation]["domain"]["nullable"] = False
            else:
                range_ = line.split(">")[0].split("/")[-1]
                dict_relations[relation]["range"]["nullable"] = False
            i += 1
            continue
            
        if "EquivalentClasses" in lines[i] and "rdf" in lines[i]:
            attribute = line.split(">")[-2].split("/")[-1]
            domain = line.split(">")[0].split("/")[-1]
            dict_attributes[attribute]["domain"]["nullable"] = False #no need to work on the range
            i += 1
            continue
            
        i += 1

print(dict_classes)
print("************************")
print (dict_relations)
print("************************")
print (dict_attributes)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-9310775ea813> in <module>()
# ----> 1 with open ("../books/book_17_06.owl", "r") as fowl:
#       2     content = fowl.read()
#       3     i = 0
#       4     lines = content.split("\n")
#       5     outstring = ""
#
# FileNotFoundError: [Errno 2] No such file or directory: '../books/book_17_06.owl'

# %%
relazioni_da_accorpare = ["hasMayor"]
relazioni_da_accorpare = []
#'character_id': {'range': {'name': 'character_id> xsd:strin'}, 'domain': {'name': 'Character', 'nullable': False}, 'functional': True, 'inv_functional': False}

# %%
#dict_attributes.keys()
# Out:
# dict_keys(['official_residence', 'city_id', 'name', 'character_id', 'start_time', 'country_id', 'end_time', 'book_id', 'title', 'description', 'author_genre', 'DoD', 'DoB', 'label', 'subtitle', 'award', 'edition_id', 'publisher_id', 'language_id', 'human_id', 'inception', 'mayor-id', 'sex'])

# %%
for attribute in dict_attributes.keys():
    if dict_attributes[attribute]["functional"] == False: #va reificata la ER-relazione e creata una nuova relazione
        #print(attribute, "**********attr")
        new_class = attribute.title()
        dict_classes[new_class] = {}
        dict_classes[new_class]["attributes"] = {}
        attribute_name = new_class.lower() + "_id"
        dict_classes[new_class]["attributes"][attribute_name] = {}
        dict_classes[new_class]["attributes"][attribute_name]["typ"] = "varchar (255)"
        dict_classes[new_class]["attributes"][attribute_name]["nullable"] = False

        new_relation = "has" + attribute.title()
        dict_relations[new_relation] = {}
        dict_relations[new_relation]["domain"] = {}
        dict_relations[new_relation]["domain"]["name"] = dict_attributes[attribute]["domain"]["name"]
        dict_relations[new_relation]["domain"]["nullable"] = dict_attributes[attribute]["domain"]["nullable"]
        dict_relations[new_relation]["range"] = {}
        dict_relations[new_relation]["range"]["name"] = new_class
        dict_relations[new_relation]["range"]["nullable"] = False
        dict_relations[new_relation]["functional"] = False
        dict_relations[new_relation]["inv_functional"] = False
    else: #assign attributes to classes
        class_ = dict_attributes[attribute]["domain"]["name"]
        #print(class_)
        nullable = dict_attributes[attribute]["domain"]["nullable"]
        typ = "varchar (255)"
        dict_classes[class_]["attributes"][attribute] = {}
        dict_classes[class_]["attributes"][attribute]["typ"] = typ
        dict_classes[class_]["attributes"][attribute]["nullable"] = nullable


for relation in dict_relations.keys():
    if relation in relazioni_da_accorpare and dict_relations[relation]["functional"] == True: #va accorpata, con precedenza sul dominio
        #print(relation, "**********")
        class_ = dict_relations[relation]["domain"]["name"]
        new_attribute = dict_relations[relation]["range"]["name"]
        nullable = dict_relations[relation]["domain"]["nullable"]
        typ = "varchar (255)"
        dict_classes[class_]["attributes"][relation] = {}
        dict_classes[class_]["attributes"][relation]["typ"] = typ
        dict_classes[class_]["attributes"][relation]["nullable"] = nullable
    elif relation in relazioni_da_accorpare and dict_relations[relation]["inv_functional"] == True:
        #print(relation, "*INV**********")
        class_ = dict_relations[relation]["range"]["name"]
        new_attribute = dict_relations[relation]["domain"]["name"]
        nullable = dict_relations[relation]["range"]["nullable"]
        typ = "varchar (255)"
        dict_classes[class_]["attributes"][relation] = {}
        dict_classes[class_]["attributes"][relation]["typ"] = typ
        dict_classes[class_]["attributes"][relation]["nullable"] = nullable
        dict_classes[class_]["attributes"][relation]["references"] = new_attribute
    else: 
        #print(relation)
        domain = dict_relations[relation]["domain"]["name"]
        range_ = dict_relations[relation]["range"]["name"]
        dict_classes[relation] = {}
        dict_classes[relation]["attributes"] = {}
        dict_classes[relation]["attributes"][domain.lower() + "_id"] = {}
        dict_classes[relation]["attributes"][domain.lower() + "_id"]["references"] = domain
        dict_classes[relation]["attributes"][domain.lower() + "_id"]["typ"] = "varchar (255)"
        dict_classes[relation]["attributes"][domain.lower() + "_id"]["nullable"] = dict_relations[relation]["domain"]["nullable"]
        dict_classes[relation]["attributes"][range_.lower() + "_id"] = {}
        dict_classes[relation]["attributes"][range_.lower() + "_id"]["references"] = range_
        dict_classes[relation]["attributes"][range_.lower() + "_id"]["typ"] = "varchar (255)"
        dict_classes[relation]["attributes"][range_.lower() + "_id"]["nullable"] = dict_relations[relation]["range"]["nullable"]


print(dict_classes)
print("************************")
print (dict_relations)
print("************************")
print (dict_attributes)    
print("************************")
# Out:
# {'City': {'attributes': {'label': {'nullable': False, 'typ': 'varchar (255)'}, 'description': {'nullable': False, 'typ': 'varchar (255)'}, 'city_id': {'nullable': False, 'typ': 'varchar (255)'}}}, 'foundedBy': {'attributes': {'publisher_id': {'nullable': False, 'typ': 'varchar (255)', 'references': 'Publisher'}, 'human_id': {'nullable': True, 'typ': 'varchar (255)', 'references': 'Human'}}}, 'locatedIn': {'attributes': {'publisher_id': {'nullable': False, 'typ': 'varchar (255)', 'references': 'Publisher'}, 'country_id': {'nullable': True, 'typ': 'varchar (255)', 'references': 'Country'}}}, 'hasCharacter': {'attributes': {'book_id': {'nullable': True, 'typ': 'varchar (255)', 'references': 'Book'}, 'character_id': {'nullable': False, 'typ': 'varchar (255)', 'references': 'Character'}}}, 'Language': {'attributes': {'language_id': {'nullable': False, 'typ': 'varchar (255)'}}}, 'FictionalCity': {'attributes': {}}, 'hasAward': {'attributes': {'author_id': {'nullable': True, 'typ': 'varchar (255)', 'references': 'Author'}, 'award_id': {'nullable': False, 'typ': 'varchar (255)', 'references': 'Award'}}}, 'hasRole': {'attributes': {'human_id': {'nullable': True, 'typ': 'varchar (255)', 'references': 'Human'}, 'mayor_id': {'nullable': False, 'typ': 'varchar (255)', 'references': 'Mayor'}}}, 'Book': {'attributes': {'title': {'nullable': False, 'typ': 'varchar (255)'}, 'subtitle': {'nullable': True, 'typ': 'varchar (255)'}, 'book_id': {'nullable': False, 'typ': 'varchar (255)'}}}, 'InfluencedBy': {'attributes': {'author_id': {'nullable': True, 'typ': 'varchar (255)', 'references': 'Author'}}}, 'hasTranslator': {'attributes': {'edition_id': {'nullable': True, 'typ': 'varchar (255)', 'references': 'Edition'}, 'translator_id': {'nullable': True, 'typ': 'varchar (255)', 'references': 'Translator'}}}, 'Award': {'attributes': {'award_id': {'nullable': False, 'typ': 'varchar (255)'}}}, 'PlaceOfDeath': {'attributes': {'realcity_id': {'nullable': True, 'typ': 'varchar (255)', 'references': 'RealCity'}, 'human_id': {'nullable': True, 'typ': 'varchar (255)', 'references': 'Human'}}}, 'Publisher': {'attributes': {'publisher_id': {'nullable': False, 'typ': 'varchar (255)'}, 'inception': {'nullable': False, 'typ': 'varchar (255)'}}}, 'hasAuthor_Genre': {'attributes': {'author_id': {'nullable': True, 'typ': 'varchar (255)', 'references': 'Author'}, 'author_genre_id': {'nullable': False, 'typ': 'varchar (255)', 'references': 'Author_Genre'}}}, 'hasPublisher': {'attributes': {'publisher_id': {'nullable': False, 'typ': 'varchar (255)', 'references': 'Publisher'}, 'edition_id': {'nullable': True, 'typ': 'varchar (255)', 'references': 'Edition'}}}, 'Edition': {'attributes': {'edition_id': {'nullable': False, 'typ': 'varchar (255)'}}}, 'FictionalCharacter': {'attributes': {}}, 'hasEdition': {'attributes': {'edition_id': {'nullable': False, 'typ': 'varchar (255)', 'references': 'Edition'}, 'book_id': {'nullable': True, 'typ': 'varchar (255)', 'references': 'Book'}}}, 'hasCountry': {'attributes': {'country_id': {'nullable': True, 'typ': 'varchar (255)', 'references': 'Country'}, 'realcity_id': {'nullable': False, 'typ': 'varchar (255)', 'references': 'RealCity'}}}, 'FictionalHuman': {'attributes': {}}, 'FictionalNonHuman': {'attributes': {}}, 'RealCity': {'attributes': {'hasMayor': {'nullable': True, 'typ': 'varchar (255)'}}}, 'hasAuthor': {'attributes': {'author_id': {'nullable': False, 'typ': 'varchar (255)', 'references': 'Author'}, 'book_id': {'nullable': False, 'typ': 'varchar (255)', 'references': 'Book'}}}, 'BookWrittenIn': {'attributes': {'language_id': {'nullable': True, 'typ': 'varchar (255)', 'references': 'Language'}, 'book_id': {'nullable': False, 'typ': 'varchar (255)', 'references': 'Book'}}}, 'hasAfterwordAuthor': {'attributes': {'author_id': {'nullable': True, 'typ': 'varchar (255)', 'references': 'Author'}, 'book_id': {'nullable': True, 'typ': 'varchar (255)', 'references': 'Book'}}}, 'hasLocation': {'attributes': {'city_id': {'nullable': True ...
# ************************
# {'foundedBy': {'functional': False, 'range': {'nullable': True, 'name': 'Human'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Publisher'}}, 'locatedIn': {'functional': True, 'range': {'nullable': True, 'name': 'Country'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Publisher'}}, 'BookWrittenIn': {'functional': False, 'range': {'nullable': True, 'name': 'Language'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Book'}}, 'followedBy': {'functional': True, 'range': {'nullable': True, 'name': 'Book'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Book'}}, 'hasAward': {'functional': False, 'range': {'nullable': False, 'name': 'Award'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Author'}}, 'hasRole': {'functional': False, 'range': {'nullable': False, 'name': 'Mayor'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Human'}}, 'hasAnalog': {'functional': True, 'range': {'nullable': True, 'name': 'RealCity'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'FictionalCity'}}, 'InfluencedBy': {'functional': False, 'range': {'nullable': True, 'name': 'Author'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Author'}}, 'hasTranslator': {'functional': False, 'range': {'nullable': True, 'name': 'Translator'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Edition'}}, 'PlaceOfDeath': {'functional': True, 'range': {'nullable': True, 'name': 'RealCity'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Human'}}, 'hasAuthor_Genre': {'functional': False, 'range': {'nullable': False, 'name': 'Author_Genre'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Author'}}, 'hasPublisher': {'functional': False, 'range': {'nullable': False, 'name': 'Publisher'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Edition'}}, 'hasAuthor': {'functional': False, 'range': {'nullable': False, 'name': 'Author'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Book'}}, 'hasCharacter': {'functional': False, 'range': {'nullable': False, 'name': 'Character'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Book'}}, 'hasEdition': {'functional': True, 'range': {'nullable': False, 'name': 'Edition'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Book'}}, 'hasForewordAuthor': {'functional': False, 'range': {'nullable': True, 'name': 'Author'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Book'}}, 'hasLocation': {'functional': False, 'range': {'nullable': True, 'name': 'City'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Book'}}, 'speaks': {'functional': False, 'range': {'nullable': True, 'name': 'Language'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Translator'}}, 'PlaceOfBirth': {'functional': True, 'range': {'nullable': True, 'name': 'RealCity'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Human'}}, 'hasMayor': {'functional': True, 'range': {'nullable': False, 'name': 'Mayor'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'RealCity'}}, 'hasAfterwordAuthor': {'functional': False, 'range': {'nullable': True, 'name': 'Author'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Book'}}, 'hasUsedLanguage': {'functional': False, 'range': {'nullable': False, 'name': 'Language'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Country'}}, 'hasIllustrator': {'functional': False, 'range': {'nullable': True, 'name': 'Human'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Edition'}}, 'hasCountry': {'functional': False, 'range': {'nullable': True, 'name': 'Country'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'RealCity'}}}
# ************************
# {'official_residence': {'functional': True, 'range': {'name': 'official_residence> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Mayor'}}, 'city_id': {'functional': True, 'range': {'name': 'city_id> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'City'}}, 'name': {'functional': True, 'range': {'name': 'name> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Human'}}, 'character_id': {'functional': True, 'range': {'name': 'character_id> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Character'}}, 'start_time': {'functional': True, 'range': {'name': 'start_time> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Mayor'}}, 'country_id': {'functional': True, 'range': {'name': 'country_id> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Country'}}, 'end_time': {'functional': True, 'range': {'name': 'end_time> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Mayor'}}, 'book_id': {'functional': True, 'range': {'name': 'book_id> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Book'}}, 'title': {'functional': True, 'range': {'name': 'title> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Book'}}, 'description': {'functional': True, 'range': {'name': 'description> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'City'}}, 'author_genre': {'functional': False, 'range': {'name': 'author_genre> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Author'}}, 'DoD': {'functional': True, 'range': {'name': 'DoD> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Human'}}, 'DoB': {'functional': True, 'range': {'name': 'DoB> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Human'}}, 'label': {'functional': True, 'range': {'name': 'label> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'City'}}, 'subtitle': {'functional': True, 'range': {'name': 'subtitle> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Book'}}, 'award': {'functional': False, 'range': {'name': 'award> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': True, 'name': 'Author'}}, 'edition_id': {'functional': True, 'range': {'name': 'edition_id> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Edition'}}, 'publisher_id': {'functional': True, 'range': {'name': 'publisher_id> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Publisher'}}, 'language_id': {'functional': True, 'range': {'name': 'language_id> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Language'}}, 'human_id': {'functional': True, 'range': {'name': 'human_id> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Human'}}, 'inception': {'functional': True, 'range': {'name': 'inception> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Publisher'}}, 'mayor-id': {'functional': True, 'range': {'name': 'mayor-id> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Mayor'}}, 'sex': {'functional': True, 'range': {'name': 'sex> xsd:strin'}, 'inv_functional': False, 'domain': {'nullable': False, 'name': 'Human'}}}
# ************************

# %%
#generate strings and write to file

# %%
outstring_create = "CREATE DATABASE bookDB;\n\nUSE bookDB;\n\n"
outstring_insert = ""

with open("create.sql", "w") as cf, open("insert.sql", "w") as insf:
    for class_ in dict_classes.keys():
        outstring_create += "CREATE TABLE " + class_ + "(" + "\n"
        #print(class_)
        for attribute in dict_classes[class_]["attributes"]:
            outstring_create += "\t" + attribute
            outstring_create +=   " " + dict_classes[class_]["attributes"][attribute]["typ"] 
            if "_id" in attribute:
                outstring_create += " " + " primary key"
            elif not dict_classes[class_]["attributes"][attribute]["nullable"]:
                outstring_create += " " + "not null"
            outstring_create += ",\n"
            if "references" in (dict_classes[class_]["attributes"][attribute]).keys():
                outstring_create += "\tforeign key " + \
                "("+ attribute + ") references " + \
                dict_classes[class_]["attributes"][attribute]["references"] + "(" + \
                dict_classes[class_]["attributes"][attribute]["references"].lower() + "_id),\n"
        '''for attribute in dict_classes[class_]["attributes"]:
            if "references" in (dict_classes[class_]["attributes"][attribute]).keys():
                outstring_create += "\tprimary key (" + attribute + "," + \
                dict_classes[class_]["attributes"][attribute]["references"].lower() + "_id),\n"'''
        outstring_create = outstring_create.rstrip()[:-1] #remove comma and newline
        outstring_create += ");\n\n" 

        outstring_insert += "LOAD DATA LOCAL INFILE PATH INTO TABLE Book\nFIELDS TERMINATED BY ';'\nENCLOSED BY '\"'"+\
        "\nLINES TERMINATED BY '\\n'\nIGNORE 1 LINES;\n\n"


    print(outstring_create)
    print(outstring_insert)
    insf.write(outstring_insert)
    cf.write(outstring_create)
# Out:
# CREATE DATABASE bookDB;
#
# USE bookDB;
#
# CREATE TABLE City(
# 	label varchar (255) not null,
# 	description varchar (255) not null,
# 	city_id varchar (255)  primary key);
#
# CREATE TABLE foundedBy(
# 	publisher_id varchar (255)  primary key,
# 	foreign key (publisher_id) references Publisher(publisher_id),
# 	human_id varchar (255)  primary key,
# 	foreign key (human_id) references Human(human_id));
#
# CREATE TABLE locatedIn(
# 	publisher_id varchar (255)  primary key,
# 	foreign key (publisher_id) references Publisher(publisher_id),
# 	country_id varchar (255)  primary key,
# 	foreign key (country_id) references Country(country_id));
#
# CREATE TABLE hasCharacter(
# 	book_id varchar (255)  primary key,
# 	foreign key (book_id) references Book(book_id),
# 	character_id varchar (255)  primary key,
# 	foreign key (character_id) references Character(character_id));
#
# CREATE TABLE Language(
# 	language_id varchar (255)  primary key);
#
# CREATE TABLE FictionalCity);
#
# CREATE TABLE hasAward(
# 	author_id varchar (255)  primary key,
# 	foreign key (author_id) references Author(author_id),
# 	award_id varchar (255)  primary key,
# 	foreign key (award_id) references Award(award_id));
#
# CREATE TABLE hasRole(
# 	human_id varchar (255)  primary key,
# 	foreign key (human_id) references Human(human_id),
# 	mayor_id varchar (255)  primary key,
# 	foreign key (mayor_id) references Mayor(mayor_id));
#
# CREATE TABLE Book(
# 	title varchar (255) not null,
# 	subtitle varchar (255),
# 	book_id varchar (255)  primary key);
#
# CREATE TABLE InfluencedBy(
# 	author_id varchar (255)  primary key,
# 	foreign key (author_id) references Author(author_id));
#
# CREATE TABLE hasTranslator(
# 	edition_id varchar (255)  primary key,
# 	foreign key (edition_id) references Edition(edition_id),
# 	translator_id varchar (255)  primary key,
# 	foreign key (translator_id) references Translator(translator_id));
#
# CREATE TABLE Award(
# 	award_id varchar (255)  primary key);
#
# CREATE TABLE PlaceOfDeath(
# 	realcity_id varchar (255)  primary key,
# 	foreign key (realcity_id) references RealCity(realcity_id),
# 	human_id varchar (255)  primary key,
# 	foreign key (human_id) references Human(human_id));
#
# CREATE TABLE Publisher(
# 	publisher_id varchar (255)  primary key,
# 	inception varchar (255) not null);
#
# CREATE TABLE hasAuthor_Genre(
# 	author_id varchar (255)  primary key,
# 	foreign key (author_id) references Author(author_id),
# 	author_genre_id varchar (255)  primary key,
# 	foreign key (author_genre_id) references Author_Genre(author_genre_id));
#
# CREATE TABLE hasPublisher(
# 	publisher_id varchar (255)  primary key,
# 	foreign key (publisher_id) references Publisher(publisher_id),
# 	edition_id varchar (255)  primary key,
# 	foreign key (edition_id) references Edition(edition_id));
#
# CREATE TABLE Edition(
# 	edition_id varchar (255)  primary key);
#
# CREATE TABLE FictionalCharacter);
#
# CREATE TABLE hasEdition(
# 	edition_id varchar (255)  primary key,
# 	foreign key (edition_id) references Edition(edition_id),
# 	book_id varchar (255)  primary key,
# 	foreign key (book_id) references Book(book_id));
#
# CREATE TABLE hasCountry(
# 	country_id varchar (255)  primary key,
# 	foreign key (country_id) references Country(country_id),
# 	realcity_id varchar (255)  primary key,
# 	foreign key (realcity_id) references RealCity(realcity_id));
#
# CREATE TABLE FictionalHuman);
#
# CREATE TABLE FictionalNonHuman);
#
# CREATE TABLE RealCity(
# 	hasMayor varchar (255));
#
# CREATE TABLE hasAuthor(
# 	author_id varchar (255)  primary key,
# 	foreign key (author_id) references Author(author_id),
# 	book_id varchar (255)  primary key,
# 	foreign key (book_id) references Book(book_id));
#
# CREATE TABLE BookWrittenIn(
# 	language_id varchar (255)  primary key,
# 	foreign key (language_id) references Language(language_id),
# 	book_id varchar (255)  primary key,
# 	foreign key (book_id) references Book(book_id));
#
# CREATE TABLE hasAfterwordAuthor(
# 	author_id varchar (255)  primary key,
# 	foreign key (author_id) references Author(author_id),
# 	book_id varchar (255)  primary key,
# 	foreign key (book_id) references Book(book_id));
#
# CREATE TABLE hasLocation(
# 	city_id varchar (255)  primary key,
# 	foreign key (city_id) references City(city_id),
# 	book_id varchar (255)  primary key,
# 	foreign key (book_id) references Book(book_id));
#
# CREATE TABLE hasForewordAuthor(
# 	author_id varchar (255)  primary key,
# 	foreign key (author_id) references Author(author_id),
# 	book_id varchar (255)  primary key,
# 	foreign key (book_id) references Book(book_id));
#
# CREATE TABLE speaks(
# 	language_id varchar (255)  primary key,
# 	foreign key (language_id) references Language(language_id),
# 	translator_id varchar (255)  primary key,
# 	foreign key (translator_id) references Translator(translator_id));
#
# CREATE TABLE PlaceOfBirth(
# 	realcity_id varchar (255)  primary key,
# 	foreign key (realcity_id) references RealCity(realcity_id),
# 	human_id varchar (255)  primary key,
# 	foreign key (human_id) references Human(human_id));
#
# CREATE TABLE Country(
# 	country_id varchar (255)  primary key);
#
# CREATE TABLE Character(
# 	character_id varchar (255)  primary key);
#
# CREATE TABLE hasUsedLanguage(
# 	country_id varchar (255)  primary key,
# 	foreign key (country_id) references Country(country_id),
# 	language_id varchar (255)  primary key,
# 	foreign key (language_id) references Language(language_id));
#
# CREATE TABLE followedBy(
# 	book_id varchar (255)  primary key,
# 	foreign key (book_id) references Book(book_id));
#
# CREATE TABLE Author);
#
# CREATE TABLE Human(
# 	human_id varchar (255)  primary key,
# 	sex varchar (255) not null,
# 	DoD varchar (255),
# 	DoB varchar (255) not null,
# 	name varchar (255) not null);
#
# CREATE TABLE hasIllustrator(
# 	edition_id varchar (255)  primary key,
# 	foreign key (edition_id) references Edition(edition_id),
# 	human_id varchar (255)  primary key,
# 	foreign key (human_id) references Human(human_id));
#
# CREATE TABLE Translator);
#
# CREATE TABLE Author_Genre(
# 	author_genre_id varchar (255)  primary key);
#
# CREATE TABLE hasAnalog(
# 	fictionalcity_id varchar (255)  primary key,
# 	foreign key (fictionalcity_id) references FictionalCity(fictionalcity_id),
# 	realcity_id varchar (255)  primary key,
# 	foreign key (realcity_id) references RealCity(realcity_id));
#
# CREATE TABLE Mayor(
# 	end_time varchar (255),
# 	official_residence varchar (255) not null,
# 	mayor-id varchar (255) not null,
# 	start_time varchar (255) not null);
#
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;
#
# LOAD DATA LOCAL INFILE PATH INTO TABLE Book
# FIELDS TERMINATED BY ';'
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 LINES;

# %%
base_iri = "http://books/"
outstring_mappings = "<?xml version=\"1.0\" encoding=\"UTF-8\"?>\n" + \
"<OBDA version=\"1.0\">\n" + \
    "<dataSource databaseDriver=\"org.postgresql.Driver\" databaseName=\"\"\n"+\
        "databasePassword=\"postgres\"\n"+\
        "databaseURL=\"jdbc:postgresql://localhost/comics_db\"\n"+\
        "databaseUsername=\"postgres\" name=\"datasource\"/>\n"+\
    "<prefixes>\n"+\
        "<prefix name=\"owl:\" namespace=\"http://www.w3.org/2002/07/owl#\"/>\n"+\
        "<prefix name=\"rdf:\" namespace=\"http://www.w3.org/1999/02/22-rdf-syntax-ns#\"/>\n"+\
        "<prefix name=\"sh:\" namespace=\"" + base_iri + "/#>\n"+\
        "<prefix name=\"xsd:\" namespace=\"http://www.w3.org/2001/XMLSchema#\"/>\n"+\
        "<prefix name=\":\" namespace=\"" + base_iri + ">\n"+\
        "<prefix name=\"xml:\" namespace=\"http://www.w3.org/XML/1998/namespace\"/>\n"+\
        "<prefix name=\"rdfs:\" namespace=\"http://www.w3.org/2000/01/rdf-schema#\"/>\n"+\
    "</prefixes>\n"

with open("book_mappings.xml", "w") as mapf:
    
    #templates
    outstring_mappings += "<templates>\n"
    for class_ in dict_classes.keys():
        outstring_mappings += "<template>http://books/" + class_.lower() + "_{_}</template>\n"
    outstring_mappings += "</templates>\n"
    
    #mappings, sql included
    outstring_mappings += "<mappings>\n"
    mapping_counter = 0
    for class_ in dict_classes.keys():
        mapping_counter += 1
        from_relation = False
        for attribute in dict_classes[class_]["attributes"]:
            if "references" in (dict_classes[class_]["attributes"][attribute]).keys():
                from_relation = True
                break
        if from_relation:
            word = "role"
        else:
            word = "concept "
        outstring_mappings += "<ontologyPredicateMapping id=\"M" + str(mapping_counter) + "_" + class_ + "\">\n" + \
        "<" + word + "string=" + base_iri + "#" + class_ + ">"
        outstring_mappings += "<template>" + base_iri + class_.lower() + ">"
    outstring_mappings += "</mappings>\n<blocks/>\n<constraints/>\n</OBDA>"

    print (outstring_mappings)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <OBDA version="1.0">
# <dataSource databaseDriver="org.postgresql.Driver" databaseName=""
# databasePassword="postgres"
# databaseURL="jdbc:postgresql://localhost/comics_db"
# databaseUsername="postgres" name="datasource"/>
# <prefixes>
# <prefix name="owl:" namespace="http://www.w3.org/2002/07/owl#"/>
# <prefix name="rdf:" namespace="http://www.w3.org/1999/02/22-rdf-syntax-ns#"/>
# <prefix name="sh:" namespace="http://books//#>
# <prefix name="xsd:" namespace="http://www.w3.org/2001/XMLSchema#"/>
# <prefix name=":" namespace="http://books/>
# <prefix name="xml:" namespace="http://www.w3.org/XML/1998/namespace"/>
# <prefix name="rdfs:" namespace="http://www.w3.org/2000/01/rdf-schema#"/>
# </prefixes>
# <templates>
# <template>http://books/city_{_}</template>
# <template>http://books/foundedby_{_}</template>
# <template>http://books/locatedin_{_}</template>
# <template>http://books/hascharacter_{_}</template>
# <template>http://books/language_{_}</template>
# <template>http://books/fictionalcity_{_}</template>
# <template>http://books/hasaward_{_}</template>
# <template>http://books/hasrole_{_}</template>
# <template>http://books/book_{_}</template>
# <template>http://books/influencedby_{_}</template>
# <template>http://books/hastranslator_{_}</template>
# <template>http://books/award_{_}</template>
# <template>http://books/placeofdeath_{_}</template>
# <template>http://books/publisher_{_}</template>
# <template>http://books/hasauthor_genre_{_}</template>
# <template>http://books/haspublisher_{_}</template>
# <template>http://books/edition_{_}</template>
# <template>http://books/fictionalcharacter_{_}</template>
# <template>http://books/hasedition_{_}</template>
# <template>http://books/hascountry_{_}</template>
# <template>http://books/fictionalhuman_{_}</template>
# <template>http://books/fictionalnonhuman_{_}</template>
# <template>http://books/realcity_{_}</template>
# <template>http://books/hasauthor_{_}</template>
# <template>http://books/bookwrittenin_{_}</template>
# <template>http://books/hasafterwordauthor_{_}</template>
# <template>http://books/haslocation_{_}</template>
# <template>http://books/hasforewordauthor_{_}</template>
# <template>http://books/speaks_{_}</template>
# <template>http://books/placeofbirth_{_}</template>
# <template>http://books/country_{_}</template>
# <template>http://books/character_{_}</template>
# <template>http://books/hasusedlanguage_{_}</template>
# <template>http://books/followedby_{_}</template>
# <template>http://books/author_{_}</template>
# <template>http://books/human_{_}</template>
# <template>http://books/hasillustrator_{_}</template>
# <template>http://books/translator_{_}</template>
# <template>http://books/author_genre_{_}</template>
# <template>http://books/hasanalog_{_}</template>
# <template>http://books/mayor_{_}</template>
# </templates>
# <mappings>
# <ontologyPredicateMapping id="M1_City">
# <conceptstring=http://books/#City><template>http://books/city><ontologyPredicateMapping id="M2_foundedBy">
# <rolestring=http://books/#foundedBy><template>http://books/foundedby><ontologyPredicateMapping id="M3_locatedIn">
# <rolestring=http://books/#locatedIn><template>http://books/locatedin><ontologyPredicateMapping id="M4_hasCharacter">
# <rolestring=http://books/#hasCharacter><template>http://books/hascharacter><ontologyPredicateMapping id="M5_Language">
# <conceptstring=http://books/#Language><template>http://books/language><ontologyPredicateMapping id="M6_FictionalCity">
# <conceptstring=http://books/#FictionalCity><template>http://books/fictionalcity><ontologyPredicateMapping id="M7_hasAward">
# <rolestring=http://books/#hasAward><template>http://books/hasaward><ontologyPredicateMapping id="M8_hasRole">
# <rolestring=http://books/#hasRole><template>http://books/hasrole><ontologyPredicateMapping id="M9_Book">
# <conceptstring=http://books/#Book><template>http://books/book><ontologyPredicateMapping id="M10_InfluencedBy">
# <rolestring=http://books/#InfluencedBy><template>http://books/influencedby><ontologyPredicateMapping id="M11_hasTranslator">
# <rolestring=http://books/#hasTranslator><template>http://books/hastranslator><ontologyPredicateMapping id="M12_Award">
# <conceptstring=http://books/#Award><template>http://books/award><ontologyPredicateMapping id="M13_PlaceOfDeath">
# <rolestring=http://books/#PlaceOfDeath><template>http://books/placeofdeath><ontologyPredicateMapping id="M14_Publisher">
# <conceptstring=http://books/#Publisher><template>http://books/publisher><ontologyPredicateMapping id="M15_hasAuthor_Genre">
# <rolestring=http://books/#hasAuthor_Genre><template>http://books/hasauthor_genre><ontologyPredicateMapping id="M16_hasPublisher">
# <rolestring=http://books/#hasPublisher><template>http://books/haspublisher><ontologyPredicateMapping id="M17_Edition">
# <conceptstring=http://books/#Edition><template>http://books/edition><ontologyPredicateMapping id="M18_FictionalCharacter">
# <conceptstring=http://books/#FictionalCharacter><template>http://books/fictionalcharacter><ontologyPredicateMapping id="M19_hasEdition">
# <rolestring=http://books/#hasEdition><template>http://books/hasedition><ontologyPredicateMapping id="M20_hasCountry">
# <rolestring=http://books/#hasCountry><template>http://books/hascountry><ontologyPredicateMapping id="M21_FictionalHuman">
# <conceptstring=http://books/#FictionalHuman><template>http://books/fictionalhuman><ontologyPredicateMapping id="M22_FictionalNonHuman">
# <conceptstring=http://books/#FictionalNonHuman><template>http://books/fictionalnonhuman><ontologyPredicateMapping id="M23_RealCity">
# <conceptstring=http://books/#RealCity><template>http://books/realcity><ontologyPredicateMapping id="M24_hasAuthor">
# <rolestring=http://books/#hasAuthor><template>http://books/hasauthor><ontologyPredicateMapping id="M25_BookWrittenIn">
# <rolestring=http://books/#BookWrittenIn><template>http://books/bookwrittenin><ontologyPredicateMapping id="M26_hasAfterwordAuthor">
# <rolestring=http://books/#hasAfterwordAuthor><template>http://books/hasafterwordauthor><ontologyPredicateMapping id="M27_hasLocation">
# <rolestring=http://books/#hasLocation><template>http://books/haslocation><ontologyPredicateMapping id="M28_hasForewordAuthor">
# <rolestring=http://books/#hasForewordAuthor><template>http://books/hasforewordauthor><ontologyPredicateMapping id="M29_speaks">
# <rolestring=http://books/#speaks><template>http://books/speaks><ontologyPredicateMapping id="M30_PlaceOfBirth">
# <rolestring=http://books/#PlaceOfBirth><template>http://books/placeofbirth><ontologyPredicateMapping id="M31_Country">
# <conceptstring=http://books/#Country><template>http://books/country><ontologyPredicateMapping id="M32_Character">
# <conceptstring=http://books/#Character><template>http://books/character><ontologyPredicateMapping id="M33_hasUsedLanguage">
# <rolestring=http://books/#hasUsedLanguage><template>http://books/hasusedlanguage><ontologyPredicateMapping id="M34_followedBy">
# <rolestring=http://books/#followedBy><template>http://books/followedby><ontologyPredicateMapping id="M35_Author">
# <conceptstring=http://books/#Author><template>http://books/author><ontologyPredicateMapping id="M36_Human">
# <conceptstring=http://books/#Human><template>http://books/human><ontologyPredicateMapping id="M37_hasIllustrator">
# <rolestring=http://books/#hasIllustrator><template>http://books/hasillustrator><ontologyPredicateMapping id="M38_Translator">
# <conceptstring=http://books/#Translator><template>http://books/translator><ontologyPredicateMapping id="M39_Author_Genre">
# <conceptstring=http://books/#Author_Genre><template>http://books/author_genre><ontologyPredicateMapping id="M40_hasAnalog">
# <rolestring=http://books/#hasAnalog><template>http://books/hasanalog><ontologyPredicateMapping id="M41_Mayor">
# <conceptstring=http://books/#Mayor><template>http://books/mayor></mappings>
# <blocks/>
# <constraints/>
# </OBDA>
